# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# !gdown --id 1s2ggWGqAjB-wlXkd6Pu7pM_3kqs6RhAF
# !gdown --id 1iQCM32OzxqvmDsgL5j4et-yE5W8o6afE
# !gdown --id 1bs8PHTExPfItW636-HVRVYwjjPilQVgy
# Out:
# Mounted at /content/gdrive/
# Downloading...
# From: https://drive.google.com/uc?id=1s2ggWGqAjB-wlXkd6Pu7pM_3kqs6RhAF
# To: /content/id_map.parquet
# 100% 1.20M/1.20M [00:00<00:00, 37.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1iQCM32OzxqvmDsgL5j4et-yE5W8o6afE
# To: /content/train.csv
# 42.9MB [00:00, 135MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bs8PHTExPfItW636-HVRVYwjjPilQVgy
# To: /content/test.csv
# 24.8MB [00:00, 151MB/s]

# %%
# !pip install imbalanced-learn
# !pip install scikit-learn==0.24
# !pip install tldextract
# !pip install hyperopt
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (0.24.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->imbalanced-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->imbalanced-learn) (1.0.1)
# Requirement already satisfied: scikit-learn==0.24 in /usr/local/lib/python3.7/dist-packages (0.24.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24) (2.2.0)
# Requirement already satisfied: tldextract in /usr/local/lib/python3.7/dist-packages (3.1.2)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.7/dist-packages (from tldextract) (1.5.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from tldextract) (2.10)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tldextract) (2.23.0)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract) (3.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from requests-file>=1.4->tldextract) (1.15.0)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.19.5)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (from hyperopt) (3.12.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.62.0)

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy import stats
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from functools import partial

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

import time
from tqdm import tqdm_notebook

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OrdinalEncoder

import re
from wordcloud import WordCloud
from tldextract import extract
from gensim.models import Word2Vec

import warnings
warnings.filterwarnings("ignore")

import six
from pandas.api.types import is_sparse

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV, TimeSeriesSplit
from numpy import mean
from numpy import std
from scipy.sparse import hstack
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
sys.modules['sklearn.utils.safe_indexing'] = sklearn.utils._safe_indexing

# %%
from imblearn.over_sampling import SMOTENC

# %% [markdown]
# # Support

# %%
def time_feature_extraction(data, train_flag):

    data = data.assign(
        # session start time
        session_start=lambda x: x.filter(like='time').min(axis=1),
        # session end time
        session_end=lambda x: x.filter(like='time').max(axis=1),
        # session duration
        duration=lambda x: (x.session_end - x.session_start).dt.seconds,
        # start hour in a session
        start_hour=lambda x: x.session_start.apply(lambda x: x.hour).astype('int'),
        # day of week in a session
        weekday=lambda x: x.session_start.apply(lambda x: x.dayofweek).astype('int'),
        month=lambda x: x.session_start.apply(lambda x: x.month).astype('int'),

        # count_of_nans
        nans_count=lambda x: x.filter(like='webpage').isna().sum(axis=1),
        # nunique pages
        nunique_pages=lambda x: x.filter(like='webpage').apply(lambda row: row.nunique(), axis=1) / (10 - x.nans_count)
        )

    data.loc[data["duration"]==0, "duration"] = 0.001
    data["duration"], lmbda = stats.boxcox(data.loc[:, "duration"])

    data.loc[data["start_hour"].isin([16,17,18,19]), "start_hour"] = 18

    if train_flag:
        data = data.reset_index().sort_values(['session_start', "session_id"], ignore_index=True)
        data.drop(columns=["session_start", "session_end"], inplace=True)
    else:
        data.drop(columns=["session_start", "session_end"], inplace=True)
    return data

# %%
def intersection(train, id_map):
    "seq of webpages"
    data_train = merge_data_and_domain(train, id_map).loc[:, ['webpage_update%s' % i for i in range(1, 11)]+["start_hour", "weekday"]]

    data_train.loc[:, ['webpage_update%s' % i for i in range(1, 11)]] = data_train.loc[:, ['webpage_update%s' % i for i in range(1, 11)]].fillna("")
    data_train.loc[:, "string"] = data_train.apply(lambda x: "-".join([x[i] for i in range(0,10) if x[i] != ""]), axis=1)
    data_train.loc[:, "preproc_tokens"] = data_train.loc[:, "string"].apply(lambda x: x.split('-')).values

    data_train = data_train.loc[:, ["preproc_tokens"]]

    data_train.loc[:, [".youtube", "sn gxouxg jqbe.googlevideo", ".ytimg"]] = 0

    for token in [".youtube", "sn gxouxg jqbe.googlevideo", ".ytimg"]:
        data_train[token] = data_train.loc[:, "preproc_tokens"].apply(lambda x: 1 if token in x else 0)
    data_train["intersection"] = 0
    data_train.loc[(data_train[".youtube"]==1) & (data_train["sn gxouxg jqbe.googlevideo"]==1) & (data_train[".ytimg"]==1), "intersection"] = 1

    train = pd.concat([train, data_train.loc[:, ["intersection"]]], axis=1)

    return train

# %%
def text_preprocessing_1(text):
    """text_preproc"""
    # split text by . or -
    clean_text = re.split("\.|-", text)
    # join text
    clean_text = " ".join(clean_text)
    # remove nums
    clean_text = re.sub("[0-9]", "", clean_text)
    # remove spaces
    clean_text = re.sub(' +', ' ', clean_text)
    # split
    clean_text = re.split(" ", clean_text)
    # seq must be longer then 1
    clean_text = [x for x in clean_text if len(x)>1]
    # join text
    clean_text = " ".join(clean_text)

    return clean_text

# %%
def merge_data_and_domain(data, id_map):
    """merge sub_domain + domain to full webapage"""
    for i in range(1,11):
        data = pd.merge(data, id_map.rename(columns={"id":"webpage"+str(i), 
                                                     "webpage_update":"webpage_update"+str(i)}).loc[:, ["webpage"+str(i),
                                                                                                        "webpage_update"+str(i)]], 
                        on="webpage"+str(i), how="left")
    return data

def merge_data_and_suf(data, id_map):
    """merge suf to full webapage"""
    for i in range(1,11):
        data = pd.merge(data, id_map.rename(columns={"id":"webpage"+str(i), 
                                                     "suf":"suf"+str(i)}).loc[:, ["webpage"+str(i),"suf"+str(i)]], 
                        on="webpage"+str(i), how="left")
    return data
    
def tf_idf_features(train, test, vectorizer_params, suf):
    """apply tf-idf to sub_domain + domain"""

    if suf:
        webpages_update = ['suf%s' % i for i in range(1, 11)]
    else:
        webpages_update = ['webpage_update%s' % i for i in range(1, 11)]

    train_sessions = train.loc[:, webpages_update].fillna("")
    test_sessions = test.loc[:, webpages_update].fillna("")

    train_tokens = train_sessions.apply(lambda x: "-".join([x[i] for i in range(0,10) if x[i] != ""]), axis=1)
    test_tokens = test_sessions.apply(lambda x: "-".join([x[i] for i in range(0,10) if x[i] != ""]), axis=1)
    if suf:
        print(train_tokens)

    vectorizer = TfidfVectorizer(**vectorizer_params)
    X_train = vectorizer.fit_transform(train_tokens)
    X_test = vectorizer.transform(test_tokens)
    
    return X_train, X_test, vectorizer

# %%
def sparse_to_dense(x_train, x_test):
    """sparse matrix to normal dense"""
    for column in x_train.columns:
        if is_sparse(x_train[column]):
            x_train.loc[:, column] = x_train.loc[:, column].sparse.to_dense()

    for column in x_test.columns:
        if is_sparse(x_test[column]):
            x_test.loc[:, column] = x_test.loc[:, column].sparse.to_dense()
    return x_train, x_test

# %%
def extraction(train, x_test, id_map, vectorizer_params, 
               time_features, popular_features, 
               columns_tf_idf, columns_tf_idf_suf, tf_idf, ohe_flag):

    if time_features:      
        print("extract time features")    
        train = time_feature_extraction(train, train_flag=True)
        x_test = time_feature_extraction(x_test, train_flag=False)

    if popular_features:
        print("intersection features") 
        train = intersection(train.copy(), id_map.copy())
        x_test = intersection(x_test, id_map)

    if tf_idf:
        print("apply tf idf")  
        data_train = merge_data_and_domain(train, id_map).loc[:, ['webpage_update%s' % i for i in range(1, 11)]]
        data_test = merge_data_and_domain(x_test, id_map).loc[:, ['webpage_update%s' % i for i in range(1, 11)]]
        train_tf_idf, test_tf_idf, vectorizer = tf_idf_features(train=data_train, test=data_test, vectorizer_params=vectorizer_params, suf=False)
        
        train_tf_idf = pd.DataFrame.sparse.from_spmatrix(train_tf_idf, 
                                                         columns=vectorizer.get_feature_names(), 
                                                         index=train.set_index("session_id").index)
        train_tf_idf = train_tf_idf.loc[:, columns_tf_idf]
        test_tf_idf = pd.DataFrame.sparse.from_spmatrix(test_tf_idf, 
                                                        columns=vectorizer.get_feature_names(), 
                                                        index=x_test.set_index("session_id").index)
        test_tf_idf = test_tf_idf.loc[:, columns_tf_idf]

        data_train = merge_data_and_suf(train, id_map).loc[:, ['suf%s' % i for i in range(1, 11)]]
        data_test = merge_data_and_suf(x_test, id_map).loc[:, ['suf%s' % i for i in range(1, 11)]]
        vectorizer_params={"min_df": 2, "max_df": 0.9,
                           'tokenizer': lambda s: s.split("-")
                         }
        train_tf_idf_suf, test_tf_idf_suf, vectorizer_suf = tf_idf_features(train=data_train, test=data_test, vectorizer_params=vectorizer_params, suf=True)
        train_tf_idf_suf = pd.DataFrame.sparse.from_spmatrix(train_tf_idf_suf, 
                                                    columns=vectorizer_suf.get_feature_names(), 
                                                    index=train.set_index("session_id").index)

        test_tf_idf_suf = pd.DataFrame.sparse.from_spmatrix(test_tf_idf_suf, 
                                                columns=vectorizer_suf.get_feature_names(), 
                                                index=x_test.set_index("session_id").index)
        train_tf_idf_suf = train_tf_idf_suf.loc[:, columns_tf_idf_suf]
        test_tf_idf_suf = test_tf_idf_suf.loc[:, columns_tf_idf_suf]

        train_tf_idf = pd.concat([train_tf_idf, train_tf_idf_suf], axis=1)
        test_tf_idf = pd.concat([test_tf_idf, test_tf_idf_suf], axis=1)

    # set_index
    train.set_index("session_id", inplace=True)
    x_test.set_index("session_id", inplace=True)

    x_train, y_train = train.drop(columns=["target"]), train.loc[:, ["target"]]

    # drop useless features
    other_features_list = ["time"+str(i) for i in range(1,11)]
    x_train.drop(columns=other_features_list, inplace=True)
    x_test.drop(columns=other_features_list, inplace=True)

    if ohe_flag:
        encoder = OneHotEncoder(handle_unknown="ignore")
        features_dummy_train = encoder.fit_transform(x_train.loc[:, ["weekday"]])
        features_dummy_train = pd.DataFrame.sparse.from_spmatrix(features_dummy_train, index=x_train.index)
        features_dummy_test = encoder.transform(x_test.loc[:, ["weekday"]])
        features_dummy_test = pd.DataFrame.sparse.from_spmatrix(features_dummy_test, index=x_test.index)

        cat_columns = list(range(features_dummy_test.shape[1]))

        x_train.drop(columns=["weekday"], inplace=True)
        x_test.drop(columns=["weekday"], inplace=True)

        x_train = pd.concat([features_dummy_train, x_train], axis=1)
        x_test = pd.concat([features_dummy_test, x_test], axis=1)

    columns = x_train.columns

    if tf_idf:
        x_train = pd.concat([x_train, train_tf_idf], axis=1)
        x_test = pd.concat([x_test, test_tf_idf], axis=1)
        x_train, x_test = sparse_to_dense(x_train, x_test)
        return x_train, y_train, x_test, vectorizer, columns
    else:
        x_train, x_test = sparse_to_dense(x_train, x_test)
        return x_train, y_train, x_test, columns, cat_columns

# %%
def save_submission(pred, number):
    pd.Series(
        pred, name='target', index=pd.Index(range(len(pred)), name='session_id')
    ).to_csv('/content/gdrive/MyDrive/EPAM/Week 7. Trees/HW/submissions_test/notebook_submission' + str(number) + '.csv')

# %%
def objective(space, estimator, x_train, y_train):
    time_split = TimeSeriesSplit(n_splits=5)

    params = {
        'min_child_samples': int(space['min_child_samples']),
        'reg_alpha': space['reg_alpha'],
        'reg_lambda': space['reg_lambda'],
        'num_leaves': int(space['num_leaves']),
        'n_estimators': int(space['n_estimators'])
    }
    
    # задаём модели требуемые параметры    
    estimator.set_params(**params)
    
    score = cross_val_score(estimator, x_train, y_train, scoring='roc_auc', cv=time_split).mean()
    print("AUC {:.3f} params {}".format(score, params))
    return {'loss':1 - score, 'status': STATUS_OK }

# %%
def df_results(hp_results):
    """
    Отображаем результаты hyperopt в формате DataFrame 

    :hp_results: результаты hyperop
    :return: pandas DataFrame
    """ 

    results = pd.DataFrame([{**x, **x['params']} for x in  hp_results])
    results.drop(labels=['status', 'params'], axis=1, inplace=True)
    results.sort_values(by=['loss'], ascending=False, inplace=True)
    return results

# %% [markdown]
# # Preprocessing

# %%
# the most powerful tf-idf features in logreg model (sub-domen+domen)
list_positive = ['.express', '.info jeunes', '.vk', '.melty', 'fr web img.acsta',
                '.videostep', 'khms.google', '.radio canada', 'api.bing',
                '.banque chalus', '.audienceinsights', 'demotivateur.disqus',
                '.indeed', 'media.melty', '.video', '.jobisjob', '.blogger',
                'gujynbgx.admedia', '.youwatch', 'reviewer.lavoixdunord',
                'img wikia.nocookie', 'static.programme tv', 'static.flickr',
                '.audienceinsights facebook', '.regarder film gratuit', '.bbc',
                'facebook .audienceinsights', 'static.videostep', '.exashare',
                '.blastr', 'docs.google', 'graphics.nytimes', '.reddit']

list_neg = ['.futura sciences', 'clients.google clients.google clients.google',
            'fr mg mail.yahoo', '.ztat', 'fbstatic.akamaihd', '.spin',
            'facebook', 'ba.commentcamarche', 'static.ccm', 'safebrowsing cache.google', 
            '.linkedin', '.wordreference', 'fr.openclassrooms', '.bing', 
            'clients.google clients.google', 'mail.google', 'plus.google']

features_list = list_positive + list_neg

# %%
OUTPUT_FOLDER = "/content/gdrive/MyDrive/EPAM/Week 7. Trees/HW/model_test"

# %%
train = pd.read_csv("./train.csv", index_col=0, parse_dates=[f'time{i+1}' for i in range(10)])
x_test = pd.read_csv('./test.csv', index_col=0, parse_dates=[f'time{i+1}' for i in range(10)])
x_test.reset_index(inplace=True)
id_map = pd.read_parquet("/content/id_map.parquet")

# %%
# get user's webpages 
user_frame = train.loc[train["target"]==1].reset_index(drop=True)

array = np.array([])
for element in ["webpage"+str(x) for x in range(1,11)]:
    unique_array = user_frame.loc[:, element].unique()
    array = np.concatenate([array, unique_array])
array = {x for x in array if x==x}

id_map["target"] = 0
id_map.loc[id_map["id"].isin(array), "target"] = 1

# extract "sub-domain", "domain", "suf" from url of webpage
list_ = [list(extract(id_map.loc[i].webpage)) for i in id_map.index]
id_map.loc[:, ["sub","domain","suf"]] = list_

# url preprocessing
id_map.loc[:, "domain"] = [text_preprocessing_1(text=x) for x in id_map.loc[:, "domain"].values]
id_map.loc[:, "sub"] = [text_preprocessing_1(text=x) for x in id_map.loc[:, "sub"].values]
id_map.loc[:, "sub"] = id_map.loc[:, "sub"].apply(lambda x: "" if x in ["www", "js init"] else x)
id_map["webpage_update"] = id_map.apply(lambda x: ".".join([x[3], x[4]]), axis=1)
id_map.loc[:, "webpage_update"] = id_map.loc[:, "webpage_update"].apply(lambda x: "twitter" if x in [".twitter", "platform.twitter"] else x)
id_map.loc[:, "webpage_update"] = id_map.loc[:, "webpage_update"].apply(lambda x: "facebook" if x in ["static ak.facebook", ".facebook", "connect.facebook"] else x)

sufs = ['fr', 'net', 'org', 'co.uk', 'ca', '', 'tv', 'ru', 'info', 'it',
       'ms', 'de', 'io', 'la', 'be', 'tt']

# %%
# params for tf-idf
vectorizer_params={'ngram_range': (1, 5), 'max_features': 30000,
                   "min_df": 2, "max_df": 0.7,
                   'tokenizer': lambda s: s.split("-")
                   }

# %%
# time_features + popular_features
x_train, y_train, x_test, vectorizer, columns = extraction(train=train.copy(), x_test=x_test.copy(), id_map=id_map, 
                                                            vectorizer_params=vectorizer_params, time_features=True,
                                                            popular_features=True, columns_tf_idf=features_list,
                                                            columns_tf_idf_suf=sufs,
                                                            tf_idf=True, ohe_flag=False)

x_train.fillna(0, inplace=True)
y_train.fillna(0, inplace=True)
x_test.fillna(0, inplace=True)
# Out:
# extract time features
# intersection features
# apply tf idf
# 0                                         com-com
# 1                                 com-com-com-com
# 2         org-org-org-org-org-com-com-com-com-org
# 3         com-com-com-com-com-org-com-com-org-org
# 4         com-org-com-com-org-net-org-org-org-com
#                            ...
# 159964                                com-com-com
# 159965                                com-com-com
# 159966    com-com-com-com-com-com-com-com-com-com
# 159967    com-com-com-com-com-com-com-com-com-com
# 159968                                com-com-com
# Length: 159969, dtype: object

# %% [markdown]
# ## LGBMClassifier

# %%
estimator = LGBMClassifier(boosting_type="goss", class_weight='balanced', random_state=42)

space = {
    'reg_alpha': hp.loguniform('reg_alpha', -1*np.log(10), 2*np.log(10)),
    'reg_lambda': hp.loguniform('reg_lambda', -1*np.log(10), 2*np.log(10)),
    'num_leaves': hp.quniform('num_leaves', 10, 60, 1),
    'min_child_samples': hp.quniform('min_child_samples', 20, 150, 1),
    'n_estimators': hp.quniform('n_estimators', 300, 800, 1)
    }

trials = Trials()

best = fmin(
    # функция для оптимизации 
    fn=partial(objective, estimator=estimator, x_train=x_train, y_train=y_train),
    # пространство поиска гиперпараметров
    space=space,
    # алгоритм поиска
    algo=tpe.suggest,
    # число итераций
    max_evals=600,
    # куда сохранять историю поиска
    trials=trials,
    # random state
    rstate=np.random.RandomState(1),
    # progressbar
    show_progressbar=True
    )
# Out:
# AUC 0.885 params {'min_child_samples': 95, 'reg_alpha': 10.748389964336562, 'reg_lambda': 0.5231809019230794, 'num_leaves': 57, 'n_estimators': 492}
# AUC 0.891 params {'min_child_samples': 84, 'reg_alpha': 0.1530929513192362, 'reg_lambda': 12.8213860620624, 'num_leaves': 29, 'n_estimators': 373}
# AUC 0.899 params {'min_child_samples': 72, 'reg_alpha': 1.0088338259661531, 'reg_lambda': 11.237567661049235, 'num_leaves': 11, 'n_estimators': 517}
# AUC 0.886 params {'min_child_samples': 78, 'reg_alpha': 0.10973550119216516, 'reg_lambda': 30.988248973241504, 'num_leaves': 48, 'n_estimators': 440}
# AUC 0.893 params {'min_child_samples': 74, 'reg_alpha': 1.716797160783963, 'reg_lambda': 12.89199491569798, 'num_leaves': 16, 'n_estimators': 501}
# AUC 0.897 params {'min_child_samples': 81, 'reg_alpha': 1.1982185129512832, 'reg_lambda': 42.95912191147955, 'num_leaves': 11, 'n_estimators': 585}
# AUC 0.887 params {'min_child_samples': 102, 'reg_alpha': 1.9695923033569547, 'reg_lambda': 79.92771350784264, 'num_leaves': 40, 'n_estimators': 399}
# AUC 0.883 params {'min_child_samples': 49, 'reg_alpha': 0.1950550143943726, 'reg_lambda': 8.895160416425732, 'num_leaves': 40, 'n_estimators': 490}
# AUC 0.882 params {'min_child_samples': 103, 'reg_alpha': 16.46790076636286, 'reg_lambda': 0.8880478332149855, 'num_leaves': 51, 'n_estimators': 573}
# AUC 0.884 params {'min_child_samples': 75, 'reg_alpha': 3.594638748649797, 'reg_lambda': 2.1992361138543988, 'num_leaves': 53, 'n_estimators': 640}
# AUC 0.886 params {'min_child_samples': 132, 'reg_alpha': 10.477964498145859, 'reg_lambda': 0.22358017238844569, 'num_leaves': 41, 'n_estimators': 671}
# AUC 0.880 params {'min_child_samples': 120, 'reg_alpha': 6.673302133214927, 'reg_lambda': 8.694339979690358, 'num_leaves': 47, 'n_estimators': 512}
# AUC 0.903 params {'min_child_samples': 27, 'reg_alpha': 40.11772733897041, 'reg_lambda': 24.216509786047254, 'num_leaves': 14, 'n_estimators': 302}
# AUC 0.879 params {'min_child_samples': 36, 'reg_alpha': 0.8913591399570582, 'reg_lambda': 0.41126826524531157, 'num_leaves': 41, 'n_estimators': 578}
# AUC 0.894 params {'min_child_samples': 88, 'reg_alpha': 2.712464832633385, 'reg_lambda': 2.431886577888021, 'num_leaves': 19, 'n_estimators': 340}
# AUC 0.893 params {'min_child_samples': 91, 'reg_alpha': 46.53670118088243, 'reg_lambda': 45.098008363664576, 'num_leaves': 57, 'n_estimators': 569}
# AUC 0.882 params {'min_child_samples': 49, 'reg_alpha': 2.593361979954673, 'reg_lambda': 12.67826576942509, 'num_leaves': 56, 'n_estimators': 492}
# AUC 0.895 params {'min_child_samples': 91, 'reg_alpha': 0.2959722310227185, 'reg_lambda': 29.252844507239057, 'num_leaves': 13, 'n_estimators': 344}
# AUC 0.889 params {'min_child_samples': 102, 'reg_alpha': 23.086862597534246, 'reg_lambda': 10.884518543340873, 'num_leaves': 28, 'n_estimators': 435}
# AUC 0.885 params {'min_child_samples': 81, 'reg_alpha': 21.18734744878593, 'reg_lambda': 3.7264635663328076, 'num_leaves': 53, 'n_estimators': 363}
# AUC 0.891 params {'min_child_samples': 22, 'reg_alpha': 96.5594560812191, 'reg_lambda': 95.10088882787574, 'num_leaves': 22, 'n_estimators': 712}
# AUC 0.890 params {'min_child_samples': 59, 'reg_alpha': 0.38907567833382367, 'reg_lambda': 5.829882775930693, 'num_leaves': 25, 'n_estimators': 791}
# AUC 0.899 params {'min_child_samples': 25, 'reg_alpha': 0.6418574179369649, 'reg_lambda': 24.19644873604462, 'num_leaves': 10, 'n_estimators': 741}
# AUC 0.884 params {'min_child_samples': 60, 'reg_alpha': 98.15320749908423, 'reg_lambda': 1.213993649486958, 'num_leaves': 32, 'n_estimators': 313}
# AUC 0.895 params {'min_child_samples': 34, 'reg_alpha': 5.039570617037989, 'reg_lambda': 4.64791545996685, 'num_leaves': 16, 'n_estimators': 306}
# AUC 0.893 params {'min_child_samples': 140, 'reg_alpha': 45.146633042114715, 'reg_lambda': 57.77915035195345, 'num_leaves': 21, 'n_estimators': 433}
# AUC 0.895 params {'min_child_samples': 64, 'reg_alpha': 0.6239707520019888, 'reg_lambda': 20.005585163918113, 'num_leaves': 16, 'n_estimators': 630}
# AUC 0.896 params {'min_child_samples': 118, 'reg_alpha': 0.39510398603294067, 'reg_lambda': 1.613024943443631, 'num_leaves': 13, 'n_estimators': 752}
# AUC 0.884 params {'min_child_samples': 41, 'reg_alpha': 47.62573028489772, 'reg_lambda': 5.68664104570788, 'num_leaves': 25, 'n_estimators': 532}
# AUC 0.888 params {'min_child_samples': 49, 'reg_alpha': 10.867105298595314, 'reg_lambda': 22.191468437898, 'num_leaves': 35, 'n_estimators': 454}
# AUC 0.900 params {'min_child_samples': 66, 'reg_alpha': 1.3984577026423088, 'reg_lambda': 81.4062491850804, 'num_leaves': 10, 'n_estimators': 402}
# AUC 0.891 params {'min_child_samples': 30, 'reg_alpha': 5.9559966043631185, 'reg_lambda': 74.05214568520745, 'num_leaves': 35, 'n_estimators': 390}
# AUC 0.896 params {'min_child_samples': 67, 'reg_alpha': 1.4044429496355664, 'reg_lambda': 92.63580826302481, 'num_leaves': 20, 'n_estimators': 323}
# AUC 0.899 params {'min_child_samples': 21, 'reg_alpha': 0.10387748093950083, 'reg_lambda': 40.678764884364554, 'num_leaves': 25, 'n_estimators': 410}
# AUC 0.903 params {'min_child_samples': 55, 'reg_alpha': 33.801679042779114, 'reg_lambda': 17.005378202432382, 'num_leaves': 14, 'n_estimators': 464}
# AUC 0.890 params {'min_child_samples': 54, 'reg_alpha': 35.209030446072966, 'reg_lambda': 16.646426206694485, 'num_leaves': 30, 'n_estimators': 461}
# AUC 0.885 params {'min_child_samples': 41, 'reg_alpha': 56.50831929232287, 'reg_lambda': 0.1001732249549739, 'num_leaves': 18, 'n_estimators': 537}
# AUC 0.893 params {'min_child_samples': 43, 'reg_alpha': 78.54383391316553, 'reg_lambda': 16.80493013400272, 'num_leaves': 14, 'n_estimators': 366}
# AUC 0.894 params {'min_child_samples': 31, 'reg_alpha': 31.227361486748315, 'reg_lambda': 8.061579110203736, 'num_leaves': 23, 'n_estimators': 621}
# AUC 0.888 params {'min_child_samples': 27, 'reg_alpha': 10.810314617075138, 'reg_lambda': 31.933853300530327, 'num_leaves': 44, 'n_estimators': 471}
# AUC 0.877 params {'min_child_samples': 51, 'reg_alpha': 66.66244075703428, 'reg_lambda': 0.6572691629024496, 'num_leaves': 37, 'n_estimators': 670}
# AUC 0.889 params {'min_child_samples': 73, 'reg_alpha': 15.78440909752764, 'reg_lambda': 2.9163437104979315, 'num_leaves': 28, 'n_estimators': 606}
# AUC 0.886 params {'min_child_samples': 112, 'reg_alpha': 7.6378116074881115, 'reg_lambda': 52.17436985933196, 'num_leaves': 31, 'n_estimators': 417}
# AUC 0.896 params {'min_child_samples': 39, 'reg_alpha': 15.507872904867755, 'reg_lambda': 8.61218802631589, 'num_leaves': 18, 'n_estimators': 300}
# AUC 0.901 params {'min_child_samples': 56, 'reg_alpha': 4.379472714810185, 'reg_lambda': 37.02625788578839, 'num_leaves': 12, 'n_estimators': 381}
# AUC 0.897 params {'min_child_samples': 20, 'reg_alpha': 28.73199656027931, 'reg_lambda': 6.532132186529365, 'num_leaves': 16, 'n_estimators': 343}
# AUC 0.886 params {'min_child_samples': 46, 'reg_alpha': 9.103941266794376, 'reg_lambda': 14.703246978118019, 'num_leaves': 33, 'n_estimators': 560}
# AUC 0.892 params {'min_child_samples': 96, 'reg_alpha': 14.690616460217699, 'reg_lambda': 60.67694924580347, 'num_leaves': 38, 'n_estimators': 502}
# AUC 0.880 params {'min_child_samples': 80, 'reg_alpha': 2.123437137024153, 'reg_lambda': 4.525174990729511, 'num_leaves': 48, 'n_estimators': 537}
# AUC 0.883 params {'min_child_samples': 70, 'reg_alpha': 3.617788456654639, 'reg_lambda': 2.0751538102193177, 'num_leaves': 45, 'n_estimators': 595}
# AUC 0.889 params {'min_child_samples': 85, 'reg_alpha': 23.327641618411466, 'reg_lambda': 9.928153410741901, 'num_leaves': 28, 'n_estimators': 474}
# AUC 0.902 params {'min_child_samples': 62, 'reg_alpha': 0.14303938944205996, 'reg_lambda': 0.24356007581612873, 'num_leaves': 15, 'n_estimators': 692}
# AUC 0.899 params {'min_child_samples': 76, 'reg_alpha': 75.47541303364733, 'reg_lambda': 25.030231174289842, 'num_leaves': 11, 'n_estimators': 328}
# AUC 0.893 params {'min_child_samples': 35, 'reg_alpha': 39.019688729450664, 'reg_lambda': 1.1652094295440154, 'num_leaves': 26, 'n_estimators': 359}
# AUC 0.880 params {'min_child_samples': 132, 'reg_alpha': 20.067735362664042, 'reg_lambda': 11.91523138593761, 'num_leaves': 59, 'n_estimators': 656}
# AUC 0.888 params {'min_child_samples': 55, 'reg_alpha': 96.65706227803724, 'reg_lambda': 3.5213263614617976, 'num_leaves': 18, 'n_estimators': 521}
# AUC 0.890 params {'min_child_samples': 45, 'reg_alpha': 13.076166948195809, 'reg_lambda': 32.91445485683377, 'num_leaves': 22, 'n_estimators': 796}
# AUC 0.884 params {'min_child_samples': 95, 'reg_alpha': 60.54598713301826, 'reg_lambda': 1.837849343252277, 'num_leaves': 23, 'n_estimators': 482}
# AUC 0.885 params {'min_child_samples': 24, 'reg_alpha': 26.8288706618332, 'reg_lambda': 6.864738881509048, 'num_leaves': 51, 'n_estimators': 455}
# AUC 0.904 params {'min_child_samples': 38, 'reg_alpha': 0.88345720593643, 'reg_lambda': 2.799671391824568, 'num_leaves': 10, 'n_estimators': 438}
# AUC 0.907 params {'min_child_samples': 30, 'reg_alpha': 0.9379787689939807, 'reg_lambda': 0.43517290287976745, 'num_leaves': 11, 'n_estimators': 443}
# AUC 0.904 params {'min_child_samples': 38, 'reg_alpha': 0.2693563097708867, 'reg_lambda': 0.11205553055803501, 'num_leaves': 11, 'n_estimators': 433}
# AUC 0.891 params {'min_child_samples': 147, 'reg_alpha': 0.8484531256541485, 'reg_lambda': 0.3083638550168265, 'num_leaves': 19, 'n_estimators': 421}
# AUC 0.884 params {'min_child_samples': 105, 'reg_alpha': 0.5338076865492735, 'reg_lambda': 0.13939804554352594, 'num_leaves': 43, 'n_estimators': 555}
# AUC 0.892 params {'min_child_samples': 33, 'reg_alpha': 0.1645262501967835, 'reg_lambda': 0.5647662331416323, 'num_leaves': 33, 'n_estimators': 502}
# AUC 0.904 params {'min_child_samples': 38, 'reg_alpha': 0.2848227059125285, 'reg_lambda': 0.1377446546249092, 'num_leaves': 10, 'n_estimators': 427}
# AUC 0.904 params {'min_child_samples': 30, 'reg_alpha': 0.9290254758728413, 'reg_lambda': 0.17025466021861504, 'num_leaves': 12, 'n_estimators': 445}
# AUC 0.900 params {'min_child_samples': 30, 'reg_alpha': 0.8759635431346686, 'reg_lambda': 0.3758552438330613, 'num_leaves': 12, 'n_estimators': 383}
# AUC 0.894 params {'min_child_samples': 27, 'reg_alpha': 1.09639940212664, 'reg_lambda': 0.7523683779195688, 'num_leaves': 17, 'n_estimators': 517}
# AUC 0.890 params {'min_child_samples': 47, 'reg_alpha': 1.837504118889638, 'reg_lambda': 0.1627629235854711, 'num_leaves': 20, 'n_estimators': 447}
# AUC 0.896 params {'min_child_samples': 22, 'reg_alpha': 0.3773837772124676, 'reg_lambda': 1.1826182252894821, 'num_leaves': 15, 'n_estimators': 397}
# AUC 0.903 params {'min_child_samples': 43, 'reg_alpha': 0.47063055543438137, 'reg_lambda': 0.1915131509989611, 'num_leaves': 13, 'n_estimators': 486}
# AUC 0.902 params {'min_child_samples': 51, 'reg_alpha': 0.7032711127019281, 'reg_lambda': 0.4865762485921411, 'num_leaves': 12, 'n_estimators': 410}
# AUC 0.890 params {'min_child_samples': 60, 'reg_alpha': 2.4945069245023626, 'reg_lambda': 0.9290656114763237, 'num_leaves': 26, 'n_estimators': 445}
# AUC 0.906 params {'min_child_samples': 27, 'reg_alpha': 1.5309349618386447, 'reg_lambda': 0.3142122818979729, 'num_leaves': 10, 'n_estimators': 355}
# AUC 0.905 params {'min_child_samples': 68, 'reg_alpha': 1.565665205148941, 'reg_lambda': 0.2748613519303035, 'num_leaves': 10, 'n_estimators': 322}
# AUC 0.887 params {'min_child_samples': 110, 'reg_alpha': 1.498187169740825, 'reg_lambda': 0.28402464808566114, 'num_leaves': 21, 'n_estimators': 352}
# AUC 0.894 params {'min_child_samples': 130, 'reg_alpha': 3.4654200697106536, 'reg_lambda': 0.39457992451824053, 'num_leaves': 15, 'n_estimators': 318}
# AUC 0.887 params {'min_child_samples': 71, 'reg_alpha': 2.819387506657257, 'reg_lambda': 1.4555282938643939, 'num_leaves': 23, 'n_estimators': 334}
# AUC 0.900 params {'min_child_samples': 85, 'reg_alpha': 1.2123729746897862, 'reg_lambda': 0.4815421188379608, 'num_leaves': 14, 'n_estimators': 372}
# AUC 0.899 params {'min_child_samples': 69, 'reg_alpha': 0.231454690743738, 'reg_lambda': 0.8886377040956552, 'num_leaves': 16, 'n_estimators': 306}
# AUC 0.883 params {'min_child_samples': 120, 'reg_alpha': 4.112203390813942, 'reg_lambda': 0.21353475972772967, 'num_leaves': 55, 'n_estimators': 349}
# AUC 0.892 params {'min_child_samples': 91, 'reg_alpha': 2.164262839506133, 'reg_lambda': 0.2793863627362992, 'num_leaves': 20, 'n_estimators': 378}
# AUC 0.889 params {'min_child_samples': 127, 'reg_alpha': 5.431657956614288, 'reg_lambda': 0.35080352583568986, 'num_leaves': 17, 'n_estimators': 399}
# AUC 0.881 params {'min_child_samples': 79, 'reg_alpha': 1.6964198436406797, 'reg_lambda': 0.10900680303906911, 'num_leaves': 37, 'n_estimators': 360}
# AUC 0.890 params {'min_child_samples': 67, 'reg_alpha': 6.5442054665071, 'reg_lambda': 0.6826624456856983, 'num_leaves': 29, 'n_estimators': 334}
# AUC 0.888 params {'min_child_samples': 58, 'reg_alpha': 0.7037914032461472, 'reg_lambda': 0.23204042013255757, 'num_leaves': 24, 'n_estimators': 310}
# AUC 0.904 params {'min_child_samples': 99, 'reg_alpha': 1.269706784943219, 'reg_lambda': 1.0256085579320848, 'num_leaves': 11, 'n_estimators': 413}
# AUC 0.906 params {'min_child_samples': 76, 'reg_alpha': 0.3506447874708253, 'reg_lambda': 0.564860318876084, 'num_leaves': 13, 'n_estimators': 320}
# AUC 0.889 params {'min_child_samples': 145, 'reg_alpha': 0.34219556787092065, 'reg_lambda': 0.5972532416277734, 'num_leaves': 19, 'n_estimators': 388}
# AUC 0.897 params {'min_child_samples': 64, 'reg_alpha': 0.13457673052021987, 'reg_lambda': 1.5477727236816015, 'num_leaves': 17, 'n_estimators': 468}
# AUC 0.899 params {'min_child_samples': 76, 'reg_alpha': 0.204930789272988, 'reg_lambda': 0.43204263915402263, 'num_leaves': 14, 'n_estimators': 580}
# AUC 0.882 params {'min_child_samples': 52, 'reg_alpha': 0.46400429997399684, 'reg_lambda': 0.7671547800495663, 'num_leaves': 31, 'n_estimators': 778}
# AUC 0.888 params {'min_child_samples': 137, 'reg_alpha': 0.12083358015142022, 'reg_lambda': 0.13325300955228833, 'num_leaves': 21, 'n_estimators': 493}
# AUC 0.900 params {'min_child_samples': 25, 'reg_alpha': 0.5789966620768903, 'reg_lambda': 2.008727185113011, 'num_leaves': 13, 'n_estimators': 366}
# AUC 0.890 params {'min_child_samples': 89, 'reg_alpha': 0.24362642691622327, 'reg_lambda': 2.394697031560404, 'num_leaves': 24, 'n_estimators': 338}
# AUC 0.884 params {'min_child_samples': 107, 'reg_alpha': 0.16999509249738606, 'reg_lambda': 4.197187621129952, 'num_leaves': 60, 'n_estimators': 424}
# AUC 0.890 params {'min_child_samples': 33, 'reg_alpha': 0.35735467310992747, 'reg_lambda': 0.3335042844651464, 'num_leaves': 27, 'n_estimators': 300}
# AUC 0.884 params {'min_child_samples': 83, 'reg_alpha': 0.7355940300587793, 'reg_lambda': 1.296821299130937, 'num_leaves': 40, 'n_estimators': 565}
# AUC 0.894 params {'min_child_samples': 116, 'reg_alpha': 0.31699895821805074, 'reg_lambda': 0.43487644400678477, 'num_leaves': 18, 'n_estimators': 354}
# AUC 0.882 params {'min_child_samples': 48, 'reg_alpha': 0.4528975412009362, 'reg_lambda': 0.19409447149104597, 'num_leaves': 51, 'n_estimators': 477}
# AUC 0.897 params {'min_child_samples': 43, 'reg_alpha': 1.0724019155803046, 'reg_lambda': 1.018586627154355, 'num_leaves': 15, 'n_estimators': 547}
# AUC 0.880 params {'min_child_samples': 95, 'reg_alpha': 3.049125042055843, 'reg_lambda': 0.7692057179347022, 'num_leaves': 34, 'n_estimators': 597}
# AUC 0.896 params {'min_child_samples': 20, 'reg_alpha': 8.329323321644242, 'reg_lambda': 0.5555004797264134, 'num_leaves': 13, 'n_estimators': 403}
# AUC 0.888 params {'min_child_samples': 125, 'reg_alpha': 2.4296706634589462, 'reg_lambda': 0.11954456557243297, 'num_leaves': 22, 'n_estimators': 530}
# AUC 0.886 params {'min_child_samples': 73, 'reg_alpha': 0.19367460091960995, 'reg_lambda': 1.7824400783320733, 'num_leaves': 49, 'n_estimators': 372}
# AUC 0.880 params {'min_child_samples': 99, 'reg_alpha': 4.675627088717988, 'reg_lambda': 0.15930979700232592, 'num_leaves': 46, 'n_estimators': 388}
# AUC 0.881 params {'min_child_samples': 57, 'reg_alpha': 0.5426360898009247, 'reg_lambda': 3.054565729200673, 'num_leaves': 42, 'n_estimators': 327}
# AUC 0.909 params {'min_child_samples': 28, 'reg_alpha': 0.768015612392653, 'reg_lambda': 0.10023983336971172, 'num_leaves': 11, 'n_estimators': 315}
# AUC 0.888 params {'min_child_samples': 62, 'reg_alpha': 0.12042750418896692, 'reg_lambda': 0.6427198951248349, 'num_leaves': 26, 'n_estimators': 729}
# AUC 0.888 params {'min_child_samples': 40, 'reg_alpha': 0.8037783833194896, 'reg_lambda': 5.217849378875953, 'num_leaves': 29, 'n_estimators': 346}
# AUC 0.902 params {'min_child_samples': 36, 'reg_alpha': 0.41754604373086357, 'reg_lambda': 0.19889990389004597, 'num_leaves': 11, 'n_estimators': 460}
# AUC 0.896 params {'min_child_samples': 23, 'reg_alpha': 0.607485481631221, 'reg_lambda': 0.10375223037224321, 'num_leaves': 17, 'n_estimators': 509}
# AUC 0.881 params {'min_child_samples': 53, 'reg_alpha': 1.9538818906836943, 'reg_lambda': 0.48496970507628473, 'num_leaves': 39, 'n_estimators': 618}
# AUC 0.894 params {'min_child_samples': 88, 'reg_alpha': 0.2367989817861045, 'reg_lambda': 0.24983434913668343, 'num_leaves': 19, 'n_estimators': 646}
# AUC 0.889 params {'min_child_samples': 29, 'reg_alpha': 1.219257742063097, 'reg_lambda': 0.1665845907702526, 'num_leaves': 21, 'n_estimators': 676}
# AUC 0.908 params {'min_child_samples': 50, 'reg_alpha': 0.3014650388214682, 'reg_lambda': 0.1201668131382747, 'num_leaves': 12, 'n_estimators': 313}
# AUC 0.889 params {'min_child_samples': 36, 'reg_alpha': 0.2744664216762296, 'reg_lambda': 0.1214419811401655, 'num_leaves': 24, 'n_estimators': 314}
# AUC 0.907 params {'min_child_samples': 32, 'reg_alpha': 0.10493573216580906, 'reg_lambda': 0.18197450848667493, 'num_leaves': 11, 'n_estimators': 547}
# AUC 0.900 params {'min_child_samples': 45, 'reg_alpha': 1.0176471712608144, 'reg_lambda': 0.12901701524401965, 'num_leaves': 15, 'n_estimators': 526}
# AUC 0.903 params {'min_child_samples': 49, 'reg_alpha': 0.17985537375213312, 'reg_lambda': 0.1571298493740334, 'num_leaves': 12, 'n_estimators': 493}
# AUC 0.883 params {'min_child_samples': 41, 'reg_alpha': 2.2639069854861273, 'reg_lambda': 0.22476656686355254, 'num_leaves': 36, 'n_estimators': 415}
# AUC 0.894 params {'min_child_samples': 26, 'reg_alpha': 0.5128192546314481, 'reg_lambda': 0.10212195457565039, 'num_leaves': 22, 'n_estimators': 432}
# AUC 0.892 params {'min_child_samples': 22, 'reg_alpha': 0.14021449973759417, 'reg_lambda': 0.27423359458560004, 'num_leaves': 30, 'n_estimators': 453}
# AUC 0.892 params {'min_child_samples': 65, 'reg_alpha': 3.615649457908308, 'reg_lambda': 0.37500423354263385, 'num_leaves': 27, 'n_estimators': 306}
# AUC 0.881 params {'min_child_samples': 61, 'reg_alpha': 0.760580472502941, 'reg_lambda': 0.14843187554567774, 'num_leaves': 32, 'n_estimators': 396}
# AUC 0.894 params {'min_child_samples': 43, 'reg_alpha': 1.366660625136065, 'reg_lambda': 7.537209329255318, 'num_leaves': 16, 'n_estimators': 368}
# AUC 0.901 params {'min_child_samples': 29, 'reg_alpha': 1.7758380043603939, 'reg_lambda': 0.10005194802879219, 'num_leaves': 14, 'n_estimators': 406}
# AUC 0.890 params {'min_child_samples': 50, 'reg_alpha': 0.6434010279370818, 'reg_lambda': 3.696673809484914, 'num_leaves': 19, 'n_estimators': 702}
# AUC 0.892 params {'min_child_samples': 37, 'reg_alpha': 0.21489497641986086, 'reg_lambda': 0.24811402527445325, 'num_leaves': 20, 'n_estimators': 301}
# AUC 0.880 params {'min_child_samples': 34, 'reg_alpha': 0.9806260355624067, 'reg_lambda': 2.5280727419640288, 'num_leaves': 57, 'n_estimators': 338}
# AUC 0.895 params {'min_child_samples': 47, 'reg_alpha': 7.140169296169368, 'reg_lambda': 0.430298606015397, 'num_leaves': 18, 'n_estimators': 771}
# AUC 0.882 params {'min_child_samples': 53, 'reg_alpha': 0.32620457589937474, 'reg_lambda': 0.34652598297962367, 'num_leaves': 53, 'n_estimators': 383}
# AUC 0.889 params {'min_child_samples': 57, 'reg_alpha': 0.4012597786797292, 'reg_lambda': 0.3082741862783656, 'num_leaves': 23, 'n_estimators': 440}
# AUC 0.902 params {'min_child_samples': 20, 'reg_alpha': 3.1098977987057093, 'reg_lambda': 1.3789018529674912, 'num_leaves': 10, 'n_estimators': 507}
# AUC 0.897 params {'min_child_samples': 24, 'reg_alpha': 5.395827048788494, 'reg_lambda': 0.11620275478367308, 'num_leaves': 12, 'n_estimators': 422}
# AUC 0.893 params {'min_child_samples': 28, 'reg_alpha': 0.10037961667824426, 'reg_lambda': 0.21706607537127062, 'num_leaves': 25, 'n_estimators': 328}
# AUC 0.897 params {'min_child_samples': 40, 'reg_alpha': 0.2680132410766316, 'reg_lambda': 0.8271450739302325, 'num_leaves': 16, 'n_estimators': 631}
# AUC 0.899 params {'min_child_samples': 82, 'reg_alpha': 11.903845274159462, 'reg_lambda': 0.14418511781005222, 'num_leaves': 14, 'n_estimators': 590}
# AUC 0.882 params {'min_child_samples': 31, 'reg_alpha': 0.15945270313767027, 'reg_lambda': 0.6775175413998864, 'num_leaves': 49, 'n_estimators': 569}
# AUC 0.889 params {'min_child_samples': 71, 'reg_alpha': 4.223274189043129, 'reg_lambda': 14.432536796333858, 'num_leaves': 27, 'n_estimators': 470}
# AUC 0.879 params {'min_child_samples': 54, 'reg_alpha': 0.6418477237711805, 'reg_lambda': 0.996632484916134, 'num_leaves': 55, 'n_estimators': 486}
# AUC 0.905 params {'min_child_samples': 43, 'reg_alpha': 1.1742893166299315, 'reg_lambda': 0.5122979593231656, 'num_leaves': 11, 'n_estimators': 393}
# AUC 0.893 params {'min_child_samples': 20, 'reg_alpha': 9.636694508473065, 'reg_lambda': 0.20142628536432153, 'num_leaves': 20, 'n_estimators': 379}
# AUC 0.894 params {'min_child_samples': 34, 'reg_alpha': 0.442869455544888, 'reg_lambda': 1.7596923795036612, 'num_leaves': 22, 'n_estimators': 362}
# AUC 0.905 params {'min_child_samples': 24, 'reg_alpha': 0.30546787814566334, 'reg_lambda': 0.17486963210435913, 'num_leaves': 11, 'n_estimators': 613}
# AUC 0.904 params {'min_child_samples': 33, 'reg_alpha': 0.11644787839987507, 'reg_lambda': 0.1008481721526097, 'num_leaves': 13, 'n_estimators': 550}
# AUC 0.894 params {'min_child_samples': 32, 'reg_alpha': 0.19543699321151364, 'reg_lambda': 0.17152635501076544, 'num_leaves': 17, 'n_estimators': 538}
# AUC 0.904 params {'min_child_samples': 46, 'reg_alpha': 0.10509823951780448, 'reg_lambda': 0.13507065083566394, 'num_leaves': 10, 'n_estimators': 658}
# AUC 0.900 params {'min_child_samples': 26, 'reg_alpha': 0.5273156116594048, 'reg_lambda': 0.2589502076561796, 'num_leaves': 15, 'n_estimators': 605}
# AUC 0.902 params {'min_child_samples': 39, 'reg_alpha': 0.12584656722362184, 'reg_lambda': 0.18088935018099142, 'num_leaves': 12, 'n_estimators': 582}
# AUC 0.899 params {'min_child_samples': 44, 'reg_alpha': 0.15232350608942785, 'reg_lambda': 0.301305643436469, 'num_leaves': 16, 'n_estimators': 681}
# AUC 0.895 params {'min_child_samples': 31, 'reg_alpha': 0.9417473466990269, 'reg_lambda': 0.11640696893402384, 'num_leaves': 18, 'n_estimators': 521}
# AUC 0.904 params {'min_child_samples': 37, 'reg_alpha': 0.8203317893930994, 'reg_lambda': 0.3800755227139778, 'num_leaves': 11, 'n_estimators': 633}
# AUC 0.902 params {'min_child_samples': 50, 'reg_alpha': 0.48386281996513925, 'reg_lambda': 0.2259949914770636, 'num_leaves': 14, 'n_estimators': 543}
# AUC 0.903 params {'min_child_samples': 28, 'reg_alpha': 0.22924487328472182, 'reg_lambda': 0.14121524936870342, 'num_leaves': 13, 'n_estimators': 646}
# AUC 0.898 params {'min_child_samples': 59, 'reg_alpha': 0.10008290832827947, 'reg_lambda': 0.4427162147998722, 'num_leaves': 17, 'n_estimators': 497}
# AUC 0.902 params {'min_child_samples': 63, 'reg_alpha': 0.37522429278300146, 'reg_lambda': 0.1994419574178592, 'num_leaves': 10, 'n_estimators': 480}
# AUC 0.900 params {'min_child_samples': 22, 'reg_alpha': 0.2521057250316447, 'reg_lambda': 0.3347950783996059, 'num_leaves': 16, 'n_estimators': 572}
# AUC 0.902 params {'min_child_samples': 35, 'reg_alpha': 2.031369707076506, 'reg_lambda': 0.10101299065365564, 'num_leaves': 12, 'n_estimators': 553}
# AUC 0.888 params {'min_child_samples': 41, 'reg_alpha': 1.4655274875656348, 'reg_lambda': 1.1701044188401817, 'num_leaves': 21, 'n_estimators': 450}
# AUC 0.895 params {'min_child_samples': 55, 'reg_alpha': 0.1687846050087045, 'reg_lambda': 0.13189562721694642, 'num_leaves': 19, 'n_estimators': 460}
# AUC 0.898 params {'min_child_samples': 46, 'reg_alpha': 0.6860866175437637, 'reg_lambda': 0.5875776685937404, 'num_leaves': 15, 'n_estimators': 726}
# AUC 0.888 params {'min_child_samples': 78, 'reg_alpha': 0.2892451786425657, 'reg_lambda': 0.2751972058870075, 'num_leaves': 24, 'n_estimators': 347}
# AUC 0.904 params {'min_child_samples': 66, 'reg_alpha': 1.6345438413266709, 'reg_lambda': 0.15389375050378715, 'num_leaves': 10, 'n_estimators': 558}
# AUC 0.887 params {'min_child_samples': 25, 'reg_alpha': 1.112206744171566, 'reg_lambda': 0.11188845114933617, 'num_leaves': 20, 'n_estimators': 429}
# AUC 0.903 params {'min_child_samples': 30, 'reg_alpha': 0.5569696683295765, 'reg_lambda': 0.10040803676428645, 'num_leaves': 13, 'n_estimators': 514}
# AUC 0.892 params {'min_child_samples': 51, 'reg_alpha': 2.81521494889846, 'reg_lambda': 10.30932109183498, 'num_leaves': 14, 'n_estimators': 529}
# AUC 0.896 params {'min_child_samples': 21, 'reg_alpha': 0.1925406110625962, 'reg_lambda': 0.24444754278552658, 'num_leaves': 18, 'n_estimators': 657}
# AUC 0.903 params {'min_child_samples': 39, 'reg_alpha': 0.8042858034109837, 'reg_lambda': 0.8580435966910306, 'num_leaves': 15, 'n_estimators': 317}
# AUC 0.887 params {'min_child_samples': 74, 'reg_alpha': 0.41521273139116127, 'reg_lambda': 0.3963371577914921, 'num_leaves': 59, 'n_estimators': 302}
# AUC 0.884 params {'min_child_samples': 57, 'reg_alpha': 0.13993578399403034, 'reg_lambda': 0.18194860649585462, 'num_leaves': 43, 'n_estimators': 601}
# AUC 0.904 params {'min_child_samples': 36, 'reg_alpha': 0.35304503987523567, 'reg_lambda': 0.7010154966173402, 'num_leaves': 11, 'n_estimators': 407}
# AUC 0.888 params {'min_child_samples': 48, 'reg_alpha': 2.490401025363769, 'reg_lambda': 0.5097733281632466, 'num_leaves': 25, 'n_estimators': 693}
# AUC 0.889 params {'min_child_samples': 41, 'reg_alpha': 0.21969148393979515, 'reg_lambda': 0.12414030997449016, 'num_leaves': 29, 'n_estimators': 753}
# AUC 0.897 params {'min_child_samples': 32, 'reg_alpha': 0.3082785581029175, 'reg_lambda': 0.32221507240834013, 'num_leaves': 17, 'n_estimators': 330}
# AUC 0.899 params {'min_child_samples': 20, 'reg_alpha': 1.8422747152037346, 'reg_lambda': 0.22141470234550117, 'num_leaves': 12, 'n_estimators': 586}
# AUC 0.889 params {'min_child_samples': 27, 'reg_alpha': 0.5749109622502114, 'reg_lambda': 0.153052519778287, 'num_leaves': 41, 'n_estimators': 374}
# AUC 0.891 params {'min_child_samples': 69, 'reg_alpha': 1.3612881568402548, 'reg_lambda': 2.172961090636986, 'num_leaves': 23, 'n_estimators': 357}
# AUC 0.884 params {'min_child_samples': 60, 'reg_alpha': 0.935319712329179, 'reg_lambda': 5.946093079469918, 'num_leaves': 34, 'n_estimators': 623}
# AUC 0.899 params {'min_child_samples': 23, 'reg_alpha': 0.10666044891397145, 'reg_lambda': 26.728436760361497, 'num_leaves': 21, 'n_estimators': 440}
# AUC 0.898 params {'min_child_samples': 44, 'reg_alpha': 0.7300137438450807, 'reg_lambda': 73.64812259050707, 'num_leaves': 19, 'n_estimators': 339}
# AUC 0.881 params {'min_child_samples': 38, 'reg_alpha': 0.47106155993399346, 'reg_lambda': 3.3490712454962606, 'num_leaves': 39, 'n_estimators': 504}
# AUC 0.907 params {'min_child_samples': 86, 'reg_alpha': 1.090867777324247, 'reg_lambda': 0.619799477112654, 'num_leaves': 11, 'n_estimators': 311}
# AUC 0.898 params {'min_child_samples': 103, 'reg_alpha': 4.033146013128359, 'reg_lambda': 1.3189388478265813, 'num_leaves': 13, 'n_estimators': 313}
# AUC 0.894 params {'min_child_samples': 98, 'reg_alpha': 1.0723509683493162, 'reg_lambda': 4.616381385355233, 'num_leaves': 16, 'n_estimators': 346}
# AUC 0.895 params {'min_child_samples': 86, 'reg_alpha': 2.204838537181357, 'reg_lambda': 1.0329331104403512, 'num_leaves': 18, 'n_estimators': 389}
# AUC 0.887 params {'min_child_samples': 92, 'reg_alpha': 6.298196476188819, 'reg_lambda': 2.6010720027930736, 'num_leaves': 31, 'n_estimators': 323}
# AUC 0.903 params {'min_child_samples': 92, 'reg_alpha': 1.2228381840659215, 'reg_lambda': 1.7289542531762774, 'num_leaves': 10, 'n_estimators': 301}
# AUC 0.880 params {'min_child_samples': 85, 'reg_alpha': 3.2585693564220226, 'reg_lambda': 0.7611195058486739, 'num_leaves': 47, 'n_estimators': 363}
# AUC 0.896 params {'min_child_samples': 113, 'reg_alpha': 1.6524839256182167, 'reg_lambda': 1.5686039470086826, 'num_leaves': 14, 'n_estimators': 334}
# AUC 0.888 params {'min_child_samples': 105, 'reg_alpha': 0.6546659227889143, 'reg_lambda': 4.015453167675982, 'num_leaves': 20, 'n_estimators': 314}
# AUC 0.901 params {'min_child_samples': 123, 'reg_alpha': 0.8564993530381294, 'reg_lambda': 0.4852315493918575, 'num_leaves': 12, 'n_estimators': 400}
# AUC 0.888 params {'min_child_samples': 108, 'reg_alpha': 1.3138744795129125, 'reg_lambda': 1.1478947870786735, 'num_leaves': 22, 'n_estimators': 300}
# AUC 0.895 params {'min_child_samples': 81, 'reg_alpha': 2.5913616289504144, 'reg_lambda': 0.5959658250653533, 'num_leaves': 16, 'n_estimators': 421}
# AUC 0.888 params {'min_child_samples': 77, 'reg_alpha': 1.933869032172903, 'reg_lambda': 0.4078925468273176, 'num_leaves': 26, 'n_estimators': 371}
# AUC 0.903 params {'min_child_samples': 115, 'reg_alpha': 1.0233327979075082, 'reg_lambda': 0.9236678286179802, 'num_leaves': 10, 'n_estimators': 352}
# AUC 0.886 params {'min_child_samples': 97, 'reg_alpha': 3.7776981555951967, 'reg_lambda': 0.27635744025525516, 'num_leaves': 28, 'n_estimators': 383}
# AUC 0.893 params {'min_child_samples': 101, 'reg_alpha': 1.5225874832472652, 'reg_lambda': 1.4559363770910358, 'num_leaves': 15, 'n_estimators': 414}
# AUC 0.882 params {'min_child_samples': 150, 'reg_alpha': 0.409437708573581, 'reg_lambda': 2.0067972568393673, 'num_leaves': 36, 'n_estimators': 336}
# AUC 0.894 params {'min_child_samples': 88, 'reg_alpha': 4.869876101512976, 'reg_lambda': 0.6276239706070057, 'num_leaves': 19, 'n_estimators': 308}
# AUC 0.899 params {'min_child_samples': 93, 'reg_alpha': 0.6254847022326946, 'reg_lambda': 2.9019774519516224, 'num_leaves': 14, 'n_estimators': 321}
# AUC 0.901 params {'min_child_samples': 71, 'reg_alpha': 0.5484251922730953, 'reg_lambda': 19.783426371226277, 'num_leaves': 11, 'n_estimators': 356}
# AUC 0.892 params {'min_child_samples': 140, 'reg_alpha': 0.4877636672044934, 'reg_lambda': 0.35578901261072643, 'num_leaves': 17, 'n_estimators': 467}
# AUC 0.884 params {'min_child_samples': 64, 'reg_alpha': 2.879618675365679, 'reg_lambda': 1.106567900623569, 'num_leaves': 30, 'n_estimators': 397}
# AUC 0.884 params {'min_child_samples': 74, 'reg_alpha': 0.2621135081178723, 'reg_lambda': 0.7759316443355877, 'num_leaves': 45, 'n_estimators': 433}
# AUC 0.892 params {'min_child_samples': 111, 'reg_alpha': 0.8015539307606074, 'reg_lambda': 0.43235340972349096, 'num_leaves': 24, 'n_estimators': 377}
# AUC 0.905 params {'min_child_samples': 79, 'reg_alpha': 0.36162104444902027, 'reg_lambda': 0.5373200219581388, 'num_leaves': 12, 'n_estimators': 345}
# AUC 0.901 params {'min_child_samples': 101, 'reg_alpha': 2.292617674193095, 'reg_lambda': 0.2045830085225041, 'num_leaves': 13, 'n_estimators': 325}
# AUC 0.896 params {'min_child_samples': 68, 'reg_alpha': 0.9405183400614694, 'reg_lambda': 0.31116499928190383, 'num_leaves': 18, 'n_estimators': 365}
# AUC 0.884 params {'min_child_samples': 89, 'reg_alpha': 18.224756377813236, 'reg_lambda': 9.045347246601024, 'num_leaves': 52, 'n_estimators': 410}
# AUC 0.891 params {'min_child_samples': 83, 'reg_alpha': 1.1908117741434112, 'reg_lambda': 2.2620112680191142, 'num_leaves': 21, 'n_estimators': 452}
# AUC 0.899 params {'min_child_samples': 53, 'reg_alpha': 7.8726056781981955, 'reg_lambda': 0.874451534616419, 'num_leaves': 11, 'n_estimators': 477}
# AUC 0.885 params {'min_child_samples': 118, 'reg_alpha': 0.32066163145845555, 'reg_lambda': 0.23890508995677442, 'num_leaves': 33, 'n_estimators': 390}
# AUC 0.901 params {'min_child_samples': 62, 'reg_alpha': 0.7734447971913049, 'reg_lambda': 0.1004960595168465, 'num_leaves': 15, 'n_estimators': 310}
# AUC 0.896 params {'min_child_samples': 108, 'reg_alpha': 1.3704858456510507, 'reg_lambda': 5.461748949929725, 'num_leaves': 14, 'n_estimators': 343}
# AUC 0.906 params {'min_child_samples': 95, 'reg_alpha': 1.8746540440936779, 'reg_lambda': 0.6574228835083294, 'num_leaves': 10, 'n_estimators': 300}
# AUC 0.892 params {'min_child_samples': 66, 'reg_alpha': 0.7120921863390735, 'reg_lambda': 0.16840485704728866, 'num_leaves': 23, 'n_estimators': 328}
# AUC 0.896 params {'min_child_samples': 80, 'reg_alpha': 0.6033461912578031, 'reg_lambda': 44.01886877970428, 'num_leaves': 17, 'n_estimators': 421}
# AUC 0.896 params {'min_child_samples': 55, 'reg_alpha': 0.17496345738589236, 'reg_lambda': 0.12806812534305023, 'num_leaves': 19, 'n_estimators': 442}
# AUC 0.901 params {'min_child_samples': 72, 'reg_alpha': 5.345074190011209, 'reg_lambda': 0.47123107682744564, 'num_leaves': 12, 'n_estimators': 372}
# AUC 0.882 params {'min_child_samples': 130, 'reg_alpha': 1.086324659366416, 'reg_lambda': 0.3865936311347067, 'num_leaves': 55, 'n_estimators': 405}
# AUC 0.890 params {'min_child_samples': 59, 'reg_alpha': 0.45023998881421645, 'reg_lambda': 0.2897969612395999, 'num_leaves': 27, 'n_estimators': 354}
# AUC 0.904 params {'min_child_samples': 49, 'reg_alpha': 0.22424424972411364, 'reg_lambda': 0.11272716724618101, 'num_leaves': 13, 'n_estimators': 383}
# AUC 0.883 params {'min_child_samples': 121, 'reg_alpha': 3.3163205030847576, 'reg_lambda': 1.2536275721205046, 'num_leaves': 25, 'n_estimators': 493}
# AUC 0.894 params {'min_child_samples': 77, 'reg_alpha': 0.8919705229586434, 'reg_lambda': 0.19180834996862126, 'num_leaves': 20, 'n_estimators': 316}
# AUC 0.898 params {'min_child_samples': 87, 'reg_alpha': 1.5008831967288236, 'reg_lambda': 0.1453932461313244, 'num_leaves': 15, 'n_estimators': 463}
# AUC 0.888 params {'min_child_samples': 105, 'reg_alpha': 0.2739578580210065, 'reg_lambda': 12.172663619835927, 'num_leaves': 22, 'n_estimators': 331}
# AUC 0.890 params {'min_child_samples': 35, 'reg_alpha': 0.15002441249531645, 'reg_lambda': 0.2541048196399983, 'num_leaves': 38, 'n_estimators': 301}
# AUC 0.894 params {'min_child_samples': 94, 'reg_alpha': 2.0590705548565666, 'reg_lambda': 0.33196995517145816, 'num_leaves': 16, 'n_estimators': 434}
# AUC 0.903 params {'min_child_samples': 46, 'reg_alpha': 1.7002374650246677, 'reg_lambda': 1.901510178341214, 'num_leaves': 10, 'n_estimators': 397}
# AUC 0.881 params {'min_child_samples': 28, 'reg_alpha': 0.5229551835819342, 'reg_lambda': 0.5503120232409869, 'num_leaves': 50, 'n_estimators': 360}
# AUC 0.906 params {'min_child_samples': 84, 'reg_alpha': 0.39856265961262705, 'reg_lambda': 0.7248230149536316, 'num_leaves': 11, 'n_estimators': 343}
# AUC 0.892 params {'min_child_samples': 90, 'reg_alpha': 2.6340767262517284, 'reg_lambda': 0.21377417404870136, 'num_leaves': 18, 'n_estimators': 311}
# AUC 0.905 params {'min_child_samples': 25, 'reg_alpha': 0.6640178320832935, 'reg_lambda': 1.5723718211609228, 'num_leaves': 12, 'n_estimators': 487}
# AUC 0.893 params {'min_child_samples': 52, 'reg_alpha': 0.3175030253832564, 'reg_lambda': 99.10613267957406, 'num_leaves': 28, 'n_estimators': 516}
# AUC 0.882 params {'min_child_samples': 42, 'reg_alpha': 1.2821040483807253, 'reg_lambda': 3.2704736196733903, 'num_leaves': 32, 'n_estimators': 364}
# AUC 0.898 params {'min_child_samples': 74, 'reg_alpha': 4.498067902899854, 'reg_lambda': 7.225539598669427, 'num_leaves': 13, 'n_estimators': 419}
# AUC 0.897 params {'min_child_samples': 20, 'reg_alpha': 0.9472179448608191, 'reg_lambda': 0.9983142437007412, 'num_leaves': 14, 'n_estimators': 449}
# AUC 0.891 params {'min_child_samples': 136, 'reg_alpha': 0.3753609815164047, 'reg_lambda': 0.15597926471331938, 'num_leaves': 17, 'n_estimators': 379}
# AUC 0.892 params {'min_child_samples': 56, 'reg_alpha': 0.200797308374929, 'reg_lambda': 0.12195443363069847, 'num_leaves': 26, 'n_estimators': 300}
# AUC 0.896 params {'min_child_samples': 38, 'reg_alpha': 85.14481413035267, 'reg_lambda': 0.8352143870231591, 'num_leaves': 10, 'n_estimators': 336}
# AUC 0.890 params {'min_child_samples': 68, 'reg_alpha': 0.25022636687241007, 'reg_lambda': 0.3521499365203511, 'num_leaves': 21, 'n_estimators': 323}
# AUC 0.888 params {'min_child_samples': 30, 'reg_alpha': 9.10572033008489, 'reg_lambda': 0.10222863247332259, 'num_leaves': 35, 'n_estimators': 429}
# AUC 0.886 params {'min_child_samples': 100, 'reg_alpha': 1.087854339701724, 'reg_lambda': 0.48661812878015176, 'num_leaves': 23, 'n_estimators': 392}
# AUC 0.901 params {'min_child_samples': 63, 'reg_alpha': 0.4581252618179872, 'reg_lambda': 1.3381704692621617, 'num_leaves': 15, 'n_estimators': 354}
# AUC 0.880 params {'min_child_samples': 49, 'reg_alpha': 2.3162537128091105, 'reg_lambda': 51.080679169017884, 'num_leaves': 44, 'n_estimators': 716}
# AUC 0.892 params {'min_child_samples': 33, 'reg_alpha': 12.438787502669662, 'reg_lambda': 2.4957936189643535, 'num_leaves': 16, 'n_estimators': 472}
# AUC 0.902 params {'min_child_samples': 103, 'reg_alpha': 0.561848750442252, 'reg_lambda': 0.262602768043807, 'num_leaves': 12, 'n_estimators': 415}
# AUC 0.892 params {'min_child_samples': 23, 'reg_alpha': 5.865069328281449, 'reg_lambda': 0.1775076716378462, 'num_leaves': 20, 'n_estimators': 368}
# AUC 0.893 params {'min_child_samples': 59, 'reg_alpha': 1.651569554898466, 'reg_lambda': 0.604877242748731, 'num_leaves': 18, 'n_estimators': 535}
# AUC 0.882 params {'min_child_samples': 44, 'reg_alpha': 0.7656236853401165, 'reg_lambda': 0.4232338152146553, 'num_leaves': 42, 'n_estimators': 504}
# AUC 0.905 params {'min_child_samples': 81, 'reg_alpha': 0.13404733934472862, 'reg_lambda': 0.13638746734764287, 'num_leaves': 13, 'n_estimators': 345}
# AUC 0.887 params {'min_child_samples': 35, 'reg_alpha': 3.07067610729113, 'reg_lambda': 35.09495407418976, 'num_leaves': 25, 'n_estimators': 788}
# AUC 0.902 params {'min_child_samples': 97, 'reg_alpha': 0.347127590256488, 'reg_lambda': 0.2988564818304566, 'num_leaves': 14, 'n_estimators': 404}
# AUC 0.900 params {'min_child_samples': 26, 'reg_alpha': 3.603660288773986, 'reg_lambda': 0.21022325722373406, 'num_leaves': 11, 'n_estimators': 563}
# AUC 0.892 params {'min_child_samples': 114, 'reg_alpha': 1.3533813151626373, 'reg_lambda': 3.9741113362564007, 'num_leaves': 19, 'n_estimators': 317}
# AUC 0.904 params {'min_child_samples': 31, 'reg_alpha': 0.10162231563860188, 'reg_lambda': 0.17160983142738206, 'num_leaves': 11, 'n_estimators': 668}
# AUC 0.905 params {'min_child_samples': 40, 'reg_alpha': 0.11268985773226568, 'reg_lambda': 0.11576360204960531, 'num_leaves': 16, 'n_estimators': 572}
# AUC 0.901 params {'min_child_samples': 29, 'reg_alpha': 0.17696016299249837, 'reg_lambda': 0.24608687047533273, 'num_leaves': 11, 'n_estimators': 544}
# AUC 0.901 params {'min_child_samples': 20, 'reg_alpha': 0.2856523483054432, 'reg_lambda': 0.15050127678398176, 'num_leaves': 12, 'n_estimators': 745}
# AUC 0.903 params {'min_child_samples': 32, 'reg_alpha': 0.20728395190173154, 'reg_lambda': 0.10003124852684322, 'num_leaves': 10, 'n_estimators': 639}
# AUC 0.899 params {'min_child_samples': 23, 'reg_alpha': 0.5978657398585348, 'reg_lambda': 0.1873573607819374, 'num_leaves': 14, 'n_estimators': 615}
# AUC 0.901 params {'min_child_samples': 41, 'reg_alpha': 0.15592522726459251, 'reg_lambda': 0.390931746485929, 'num_leaves': 15, 'n_estimators': 596}
# AUC 0.901 params {'min_child_samples': 37, 'reg_alpha': 0.8524549572530251, 'reg_lambda': 0.29883964341192737, 'num_leaves': 13, 'n_estimators': 687}
# AUC 0.895 params {'min_child_samples': 28, 'reg_alpha': 0.43218138676476386, 'reg_lambda': 0.2291340551442923, 'num_leaves': 17, 'n_estimators': 529}
# AUC 0.903 params {'min_child_samples': 46, 'reg_alpha': 0.1343363988604871, 'reg_lambda': 0.13901553094853308, 'num_leaves': 10, 'n_estimators': 587}
# AUC 0.904 params {'min_child_samples': 35, 'reg_alpha': 0.7035739327232503, 'reg_lambda': 0.35201734605501744, 'num_leaves': 13, 'n_estimators': 701}
# AUC 0.901 params {'min_child_samples': 50, 'reg_alpha': 0.23657461479285063, 'reg_lambda': 0.1998163452994971, 'num_leaves': 16, 'n_estimators': 518}
# AUC 0.904 params {'min_child_samples': 24, 'reg_alpha': 0.5025139929474507, 'reg_lambda': 0.1159908658499585, 'num_leaves': 10, 'n_estimators': 663}
# AUC 0.899 params {'min_child_samples': 26, 'reg_alpha': 0.11914054702851033, 'reg_lambda': 0.6747573739559478, 'num_leaves': 14, 'n_estimators': 554}
# AUC 0.891 params {'min_child_samples': 21, 'reg_alpha': 0.30085597188538454, 'reg_lambda': 0.5269468315541188, 'num_leaves': 19, 'n_estimators': 647}
# AUC 0.905 params {'min_child_samples': 42, 'reg_alpha': 1.1706112049575426, 'reg_lambda': 0.15842874345161234, 'num_leaves': 12, 'n_estimators': 484}
# AUC 0.898 params {'min_child_samples': 54, 'reg_alpha': 1.0076084681302584, 'reg_lambda': 0.10176126019385803, 'num_leaves': 15, 'n_estimators': 622}
# AUC 0.894 params {'min_child_samples': 47, 'reg_alpha': 0.3568380538388691, 'reg_lambda': 0.4519208518516864, 'num_leaves': 18, 'n_estimators': 605}
# AUC 0.900 params {'min_child_samples': 34, 'reg_alpha': 0.18317684959698174, 'reg_lambda': 0.2795792877727102, 'num_leaves': 17, 'n_estimators': 577}
# AUC 0.903 params {'min_child_samples': 39, 'reg_alpha': 1.9335885040576983, 'reg_lambda': 0.1851089444960765, 'num_leaves': 11, 'n_estimators': 445}
# AUC 0.896 params {'min_child_samples': 31, 'reg_alpha': 0.4169035210822782, 'reg_lambda': 0.23197630296510538, 'num_leaves': 15, 'n_estimators': 456}
# AUC 0.906 params {'min_child_samples': 61, 'reg_alpha': 1.5078450296652752, 'reg_lambda': 0.1317808222171289, 'num_leaves': 11, 'n_estimators': 497}
# AUC 0.890 params {'min_child_samples': 44, 'reg_alpha': 0.6099506675494583, 'reg_lambda': 0.3412534727546866, 'num_leaves': 21, 'n_estimators': 758}
# AUC 0.904 params {'min_child_samples': 70, 'reg_alpha': 0.26829515477575405, 'reg_lambda': 0.5762042525928379, 'num_leaves': 13, 'n_estimators': 300}
# AUC 0.892 params {'min_child_samples': 37, 'reg_alpha': 0.854665857267918, 'reg_lambda': 0.3998814357779209, 'num_leaves': 22, 'n_estimators': 563}
# AUC 0.904 params {'min_child_samples': 76, 'reg_alpha': 0.14936315490960425, 'reg_lambda': 0.9162416164272773, 'num_leaves': 12, 'n_estimators': 545}
# AUC 0.904 params {'min_child_samples': 51, 'reg_alpha': 0.10004905091907663, 'reg_lambda': 0.26304643983831383, 'num_leaves': 16, 'n_estimators': 387}
# AUC 0.891 params {'min_child_samples': 28, 'reg_alpha': 0.4924196654227312, 'reg_lambda': 0.16823840944060287, 'num_leaves': 20, 'n_estimators': 466}
# AUC 0.898 params {'min_child_samples': 65, 'reg_alpha': 0.22022829423138174, 'reg_lambda': 0.2133209744162245, 'num_leaves': 18, 'n_estimators': 333}
# AUC 0.903 params {'min_child_samples': 57, 'reg_alpha': 1.0303463597037263, 'reg_lambda': 0.12320261250807525, 'num_leaves': 10, 'n_estimators': 523}
# AUC 0.901 params {'min_child_samples': 86, 'reg_alpha': 0.7420276620558253, 'reg_lambda': 0.7508882396546331, 'num_leaves': 12, 'n_estimators': 481}
# AUC 0.892 params {'min_child_samples': 22, 'reg_alpha': 1.2255914245467894, 'reg_lambda': 0.3163005544823433, 'num_leaves': 17, 'n_estimators': 510}
# AUC 0.900 params {'min_child_samples': 33, 'reg_alpha': 2.515531873958761, 'reg_lambda': 0.4477946736036538, 'num_leaves': 14, 'n_estimators': 324}
# AUC 0.891 params {'min_child_samples': 83, 'reg_alpha': 0.33489636227190733, 'reg_lambda': 0.1385010792336936, 'num_leaves': 24, 'n_estimators': 375}
# AUC 0.885 params {'min_child_samples': 91, 'reg_alpha': 0.638197695283713, 'reg_lambda': 1.1399737731513566, 'num_leaves': 56, 'n_estimators': 310}
# AUC 0.902 params {'min_child_samples': 110, 'reg_alpha': 2.1259542205657196, 'reg_lambda': 0.10743592810518574, 'num_leaves': 11, 'n_estimators': 728}
# AUC 0.898 params {'min_child_samples': 20, 'reg_alpha': 1.6522441560401622, 'reg_lambda': 0.10035877214837229, 'num_leaves': 14, 'n_estimators': 633}
# AUC 0.903 params {'min_child_samples': 25, 'reg_alpha': 0.5438968835926042, 'reg_lambda': 0.24088585638079799, 'num_leaves': 10, 'n_estimators': 426}
# AUC 0.905 params {'min_child_samples': 40, 'reg_alpha': 0.19165273866503893, 'reg_lambda': 0.18497890490106278, 'num_leaves': 13, 'n_estimators': 360}
# AUC 0.899 params {'min_child_samples': 47, 'reg_alpha': 43.38029448288326, 'reg_lambda': 0.6272972132010987, 'num_leaves': 15, 'n_estimators': 437}
# AUC 0.893 params {'min_child_samples': 30, 'reg_alpha': 0.38914158687351874, 'reg_lambda': 0.37288143758894476, 'num_leaves': 19, 'n_estimators': 411}
# AUC 0.880 params {'min_child_samples': 73, 'reg_alpha': 0.2462091594552588, 'reg_lambda': 0.5244240636956602, 'num_leaves': 40, 'n_estimators': 347}
# AUC 0.901 params {'min_child_samples': 53, 'reg_alpha': 0.16091175570047822, 'reg_lambda': 0.291724527102747, 'num_leaves': 16, 'n_estimators': 459}
# AUC 0.901 params {'min_child_samples': 79, 'reg_alpha': 24.214395895743785, 'reg_lambda': 0.16048401448090074, 'num_leaves': 10, 'n_estimators': 580}
# AUC 0.890 params {'min_child_samples': 43, 'reg_alpha': 0.9357665307748894, 'reg_lambda': 0.20404684470729956, 'num_leaves': 23, 'n_estimators': 336}
# AUC 0.884 params {'min_child_samples': 27, 'reg_alpha': 1.37266813796336, 'reg_lambda': 0.8314185764171786, 'num_leaves': 37, 'n_estimators': 497}
# AUC 0.892 params {'min_child_samples': 37, 'reg_alpha': 0.13005920963603862, 'reg_lambda': 0.12376502628609486, 'num_leaves': 21, 'n_estimators': 535}
# AUC 0.884 params {'min_child_samples': 94, 'reg_alpha': 0.3083459168527244, 'reg_lambda': 0.9673544463039571, 'num_leaves': 48, 'n_estimators': 677}
# AUC 0.905 params {'min_child_samples': 34, 'reg_alpha': 1.7891430298171058, 'reg_lambda': 1.4727765923401759, 'num_leaves': 11, 'n_estimators': 393}
# AUC 0.904 params {'min_child_samples': 89, 'reg_alpha': 0.6978101949540262, 'reg_lambda': 0.4698494220834885, 'num_leaves': 13, 'n_estimators': 309}
# AUC 0.896 params {'min_child_samples': 58, 'reg_alpha': 1.1229078068236626, 'reg_lambda': 0.3298176531669993, 'num_leaves': 17, 'n_estimators': 473}
# AUC 0.883 params {'min_child_samples': 66, 'reg_alpha': 2.8427905176856942, 'reg_lambda': 0.14800748449176543, 'num_leaves': 58, 'n_estimators': 375}
# AUC 0.902 params {'min_child_samples': 20, 'reg_alpha': 53.60820787658872, 'reg_lambda': 0.2621421638387091, 'num_leaves': 12, 'n_estimators': 318}
# AUC 0.901 params {'min_child_samples': 117, 'reg_alpha': 0.46702192811128534, 'reg_lambda': 0.6499925515686424, 'num_leaves': 14, 'n_estimators': 605}
# AUC 0.886 params {'min_child_samples': 48, 'reg_alpha': 0.8433473139491816, 'reg_lambda': 0.10149719371192031, 'num_leaves': 30, 'n_estimators': 354}
# AUC 0.893 params {'min_child_samples': 31, 'reg_alpha': 0.11739117739262137, 'reg_lambda': 0.22347312443214026, 'num_leaves': 19, 'n_estimators': 591}
# AUC 0.897 params {'min_child_samples': 23, 'reg_alpha': 0.5459693416607946, 'reg_lambda': 1.793870528370871, 'num_leaves': 16, 'n_estimators': 301}
# AUC 0.891 params {'min_child_samples': 45, 'reg_alpha': 6.881382355768784, 'reg_lambda': 0.11532950243725662, 'num_leaves': 15, 'n_estimators': 555}
# AUC 0.897 params {'min_child_samples': 39, 'reg_alpha': 0.20605860417130606, 'reg_lambda': 0.4036089139110947, 'num_leaves': 18, 'n_estimators': 328}
# AUC 0.891 params {'min_child_samples': 99, 'reg_alpha': 0.39256153073931077, 'reg_lambda': 0.17487566473766505, 'num_leaves': 22, 'n_estimators': 650}
# AUC 0.894 params {'min_child_samples': 62, 'reg_alpha': 4.290536893477048, 'reg_lambda': 1.2842140790605645, 'num_leaves': 20, 'n_estimators': 715}
# AUC 0.892 params {'min_child_samples': 51, 'reg_alpha': 0.28951083196314004, 'reg_lambda': 2.1680949778496172, 'num_leaves': 27, 'n_estimators': 368}
# AUC 0.880 params {'min_child_samples': 104, 'reg_alpha': 1.41609937126013, 'reg_lambda': 0.5198623097253984, 'num_leaves': 54, 'n_estimators': 383}
# AUC 0.902 params {'min_child_samples': 42, 'reg_alpha': 0.6886119232974116, 'reg_lambda': 0.7554089088408399, 'num_leaves': 10, 'n_estimators': 401}
# ...
# AUC 0.891 params {'min_child_samples': 40, 'reg_alpha': 0.22748400723657786, 'reg_lambda': 2.2620848974623384, 'num_leaves': 21, 'n_estimators': 309}
# AUC 0.898 params {'min_child_samples': 33, 'reg_alpha': 1.2998513021266425, 'reg_lambda': 0.49666864193001004, 'num_leaves': 13, 'n_estimators': 396}
# AUC 0.896 params {'min_child_samples': 23, 'reg_alpha': 0.30931341603051277, 'reg_lambda': 4.434794332006313, 'num_leaves': 17, 'n_estimators': 371}
# AUC 0.894 params {'min_child_samples': 42, 'reg_alpha': 0.1253408308942783, 'reg_lambda': 5.767096019475303, 'num_leaves': 23, 'n_estimators': 320}
# AUC 0.892 params {'min_child_samples': 28, 'reg_alpha': 0.6723733818388729, 'reg_lambda': 1.2935552803945158, 'num_leaves': 19, 'n_estimators': 426}
# AUC 0.899 params {'min_child_samples': 37, 'reg_alpha': 0.2008185617570432, 'reg_lambda': 0.8021008631633847, 'num_leaves': 15, 'n_estimators': 338}
# AUC 0.892 params {'min_child_samples': 25, 'reg_alpha': 1.015573664032415, 'reg_lambda': 13.39307775043143, 'num_leaves': 29, 'n_estimators': 386}
# AUC 0.899 params {'min_child_samples': 31, 'reg_alpha': 3.957545724288966, 'reg_lambda': 40.028283210540295, 'num_leaves': 11, 'n_estimators': 347}
# AUC 0.899 params {'min_child_samples': 20, 'reg_alpha': 1.6425564729002622, 'reg_lambda': 0.6104994264123301, 'num_leaves': 11, 'n_estimators': 786}
# AUC 0.901 params {'min_child_samples': 61, 'reg_alpha': 0.27076059405326847, 'reg_lambda': 2.569763360464544, 'num_leaves': 12, 'n_estimators': 416}
# AUC 0.900 params {'min_child_samples': 39, 'reg_alpha': 0.33847944240207584, 'reg_lambda': 2.9579068291929334, 'num_leaves': 10, 'n_estimators': 705}
# AUC 0.902 params {'min_child_samples': 23, 'reg_alpha': 0.17360198070593266, 'reg_lambda': 1.5439087029192378, 'num_leaves': 13, 'n_estimators': 312}
# AUC 0.894 params {'min_child_samples': 45, 'reg_alpha': 98.94746891678486, 'reg_lambda': 1.036507854867285, 'num_leaves': 16, 'n_estimators': 327}
# AUC 0.893 params {'min_child_samples': 35, 'reg_alpha': 0.5692192238813967, 'reg_lambda': 8.34519487765178, 'num_leaves': 20, 'n_estimators': 357}
# AUC 0.891 params {'min_child_samples': 29, 'reg_alpha': 6.252798654641522, 'reg_lambda': 3.549352487333057, 'num_leaves': 27, 'n_estimators': 370}
# AUC 0.900 params {'min_child_samples': 52, 'reg_alpha': 0.14568691507592055, 'reg_lambda': 1.9476807197592432, 'num_leaves': 15, 'n_estimators': 406}
# AUC 0.897 params {'min_child_samples': 27, 'reg_alpha': 0.42032182958377906, 'reg_lambda': 0.7128424678571628, 'num_leaves': 17, 'n_estimators': 303}
# AUC 0.902 params {'min_child_samples': 49, 'reg_alpha': 0.24924613826310232, 'reg_lambda': 1.2727982268434235, 'num_leaves': 14, 'n_estimators': 449}
# AUC 0.903 params {'min_child_samples': 33, 'reg_alpha': 0.764350057497453, 'reg_lambda': 2.315600299398295, 'num_leaves': 12, 'n_estimators': 300}
# AUC 0.904 params {'min_child_samples': 42, 'reg_alpha': 0.1164432041495167, 'reg_lambda': 5.012656650579161, 'num_leaves': 10, 'n_estimators': 332}
# AUC 0.894 params {'min_child_samples': 23, 'reg_alpha': 0.4832982257481615, 'reg_lambda': 0.9637128117063046, 'num_leaves': 18, 'n_estimators': 318}
# AUC 0.906 params {'min_child_samples': 38, 'reg_alpha': 0.3935972530470932, 'reg_lambda': 0.5702849595512803, 'num_leaves': 13, 'n_estimators': 465}
# AUC 0.907 params {'min_child_samples': 31, 'reg_alpha': 0.19508947812965774, 'reg_lambda': 0.47002575196894747, 'num_leaves': 11, 'n_estimators': 378}
# AUC 0.891 params {'min_child_samples': 20, 'reg_alpha': 0.14802641652648452, 'reg_lambda': 6.79877732529538, 'num_leaves': 40, 'n_estimators': 342}
# AUC 0.892 params {'min_child_samples': 25, 'reg_alpha': 0.2918604026681299, 'reg_lambda': 1.7741783242315239, 'num_leaves': 34, 'n_estimators': 390}
# AUC 0.890 params {'min_child_samples': 46, 'reg_alpha': 0.8850190129473638, 'reg_lambda': 0.8208138557145225, 'num_leaves': 19, 'n_estimators': 363}
# AUC 0.888 params {'min_child_samples': 55, 'reg_alpha': 21.976891020618723, 'reg_lambda': 1.135847062357152, 'num_leaves': 31, 'n_estimators': 324}
# AUC 0.898 params {'min_child_samples': 36, 'reg_alpha': 2.907520178127594, 'reg_lambda': 0.6605564307398336, 'num_leaves': 15, 'n_estimators': 311}
# AUC 0.898 params {'min_child_samples': 28, 'reg_alpha': 0.12873023333687517, 'reg_lambda': 2.7620454432052006, 'num_leaves': 14, 'n_estimators': 301}
# AUC 0.884 params {'min_child_samples': 141, 'reg_alpha': 1.9374930674905917, 'reg_lambda': 1.4202294477943511, 'num_leaves': 24, 'n_estimators': 435}
# AUC 0.903 params {'min_child_samples': 39, 'reg_alpha': 0.6258713754537023, 'reg_lambda': 3.2110655883864974, 'num_leaves': 12, 'n_estimators': 348}
# AUC 0.896 params {'min_child_samples': 33, 'reg_alpha': 12.308187912766304, 'reg_lambda': 2.1456219667119645, 'num_leaves': 16, 'n_estimators': 334}
# AUC 0.887 params {'min_child_samples': 22, 'reg_alpha': 0.32816043472188294, 'reg_lambda': 4.337940113531745, 'num_leaves': 56, 'n_estimators': 301}
# AUC 0.905 params {'min_child_samples': 48, 'reg_alpha': 0.22016575836450822, 'reg_lambda': 0.415374152664638, 'num_leaves': 10, 'n_estimators': 380}
# AUC 0.884 params {'min_child_samples': 25, 'reg_alpha': 16.399093553782226, 'reg_lambda': 0.8785378028127547, 'num_leaves': 37, 'n_estimators': 354}
# AUC 0.891 params {'min_child_samples': 43, 'reg_alpha': 0.16338582147336542, 'reg_lambda': 3.7012012290451066, 'num_leaves': 21, 'n_estimators': 412}
# AUC 0.899 params {'min_child_samples': 37, 'reg_alpha': 0.25385812463954044, 'reg_lambda': 1.1936469389655344, 'num_leaves': 13, 'n_estimators': 323}
# AUC 0.903 params {'min_child_samples': 20, 'reg_alpha': 0.10519515585610589, 'reg_lambda': 1.6964357623333073, 'num_leaves': 11, 'n_estimators': 398}
# AUC 0.891 params {'min_child_samples': 59, 'reg_alpha': 0.10133535717518724, 'reg_lambda': 2.446942762562227, 'num_leaves': 22, 'n_estimators': 365}
# AUC 0.895 params {'min_child_samples': 29, 'reg_alpha': 0.5390113715959477, 'reg_lambda': 1.9292438830199465, 'num_leaves': 18, 'n_estimators': 340}
# AUC 0.898 params {'min_child_samples': 34, 'reg_alpha': 2.4030534983602947, 'reg_lambda': 1.3949029007360358, 'num_leaves': 14, 'n_estimators': 309}
# AUC 0.902 params {'min_child_samples': 41, 'reg_alpha': 0.17911854063173566, 'reg_lambda': 0.9548763392063887, 'num_leaves': 16, 'n_estimators': 357}
# AUC 0.900 params {'min_child_samples': 31, 'reg_alpha': 1.1931994914940667, 'reg_lambda': 5.905059702208518, 'num_leaves': 10, 'n_estimators': 334}
# AUC 0.904 params {'min_child_samples': 20, 'reg_alpha': 0.39270662825121977, 'reg_lambda': 0.6831681717255412, 'num_leaves': 12, 'n_estimators': 317}
# AUC 0.886 params {'min_child_samples': 26, 'reg_alpha': 1.0252606061565313, 'reg_lambda': 0.5207567162989443, 'num_leaves': 48, 'n_estimators': 372}
# AUC 0.897 params {'min_child_samples': 53, 'reg_alpha': 0.4806523924967584, 'reg_lambda': 2.9587108011779133, 'num_leaves': 17, 'n_estimators': 425}
# AUC 0.902 params {'min_child_samples': 44, 'reg_alpha': 0.695641086584157, 'reg_lambda': 7.590765571094204, 'num_leaves': 13, 'n_estimators': 300}
# AUC 0.898 params {'min_child_samples': 23, 'reg_alpha': 0.22207760900318166, 'reg_lambda': 1.5328947948808611, 'num_leaves': 20, 'n_estimators': 388}
# AUC 0.893 params {'min_child_samples': 30, 'reg_alpha': 1.4302242785986279, 'reg_lambda': 1.11328587106517, 'num_leaves': 15, 'n_estimators': 348}
# AUC 0.890 params {'min_child_samples': 36, 'reg_alpha': 0.11616226268073813, 'reg_lambda': 2.1566834499295116, 'num_leaves': 30, 'n_estimators': 398}
# AUC 0.903 params {'min_child_samples': 50, 'reg_alpha': 0.3432660216600162, 'reg_lambda': 19.31026387485521, 'num_leaves': 11, 'n_estimators': 327}
# AUC 0.886 params {'min_child_samples': 40, 'reg_alpha': 0.13766695206413862, 'reg_lambda': 5.078270057699638, 'num_leaves': 51, 'n_estimators': 300}
# AUC 0.892 params {'min_child_samples': 26, 'reg_alpha': 0.2730311452335623, 'reg_lambda': 2.59384515344432, 'num_leaves': 19, 'n_estimators': 311}
# AUC 0.905 params {'min_child_samples': 20, 'reg_alpha': 0.10096458556474883, 'reg_lambda': 3.8825807718500696, 'num_leaves': 10, 'n_estimators': 343}
# AUC 0.899 params {'min_child_samples': 33, 'reg_alpha': 0.1922471999012096, 'reg_lambda': 0.7879000209293681, 'num_leaves': 15, 'n_estimators': 478}
# AUC 0.884 params {'min_child_samples': 47, 'reg_alpha': 0.8007391222455201, 'reg_lambda': 1.2813388418767577, 'num_leaves': 46, 'n_estimators': 357}
# AUC 0.904 params {'min_child_samples': 28, 'reg_alpha': 0.16322753401426238, 'reg_lambda': 0.5885824848697995, 'num_leaves': 13, 'n_estimators': 377}
# AUC 0.904 params {'min_child_samples': 23, 'reg_alpha': 0.23534656403828244, 'reg_lambda': 1.7037979415427933, 'num_leaves': 12, 'n_estimators': 331}
# AUC 0.893 params {'min_child_samples': 38, 'reg_alpha': 0.42592246756116287, 'reg_lambda': 16.143420630171043, 'num_leaves': 17, 'n_estimators': 764}
# AUC 0.902 params {'min_child_samples': 45, 'reg_alpha': 0.3033708625147547, 'reg_lambda': 9.458761992294193, 'num_leaves': 14, 'n_estimators': 315}
# AUC 0.898 params {'min_child_samples': 57, 'reg_alpha': 0.6012873429381722, 'reg_lambda': 11.285015232459456, 'num_leaves': 10, 'n_estimators': 453}
# AUC 0.896 params {'min_child_samples': 64, 'reg_alpha': 0.14659477243125288, 'reg_lambda': 0.9480948046405905, 'num_leaves': 18, 'n_estimators': 300}
# AUC 0.900 params {'min_child_samples': 31, 'reg_alpha': 2.128277054324408, 'reg_lambda': 0.371703294496953, 'num_leaves': 12, 'n_estimators': 403}
# AUC 0.906 params {'min_child_samples': 35, 'reg_alpha': 0.20395280809397826, 'reg_lambda': 1.485292991485355, 'num_leaves': 11, 'n_estimators': 366}
# AUC 0.896 params {'min_child_samples': 25, 'reg_alpha': 0.35912940361872586, 'reg_lambda': 3.3858347041184986, 'num_leaves': 16, 'n_estimators': 417}
# AUC 0.893 params {'min_child_samples': 40, 'reg_alpha': 0.5447017763302521, 'reg_lambda': 0.4497440753329168, 'num_leaves': 21, 'n_estimators': 387}
# AUC 0.900 params {'min_child_samples': 20, 'reg_alpha': 0.13220293774123013, 'reg_lambda': 1.9531068496468558, 'num_leaves': 13, 'n_estimators': 323}
# AUC 0.900 params {'min_child_samples': 51, 'reg_alpha': 0.8803239698880929, 'reg_lambda': 0.7491103814303244, 'num_leaves': 15, 'n_estimators': 435}
# AUC 0.888 params {'min_child_samples': 125, 'reg_alpha': 0.11902234415741746, 'reg_lambda': 4.520426590570688, 'num_leaves': 27, 'n_estimators': 349}
# AUC 0.893 params {'min_child_samples': 28, 'reg_alpha': 0.2635422131150044, 'reg_lambda': 2.294248029697459, 'num_leaves': 36, 'n_estimators': 336}
# AUC 0.893 params {'min_child_samples': 43, 'reg_alpha': 0.17967892192422566, 'reg_lambda': 1.1193695318348398, 'num_leaves': 19, 'n_estimators': 311}
# AUC 0.903 params {'min_child_samples': 32, 'reg_alpha': 0.4638919874609977, 'reg_lambda': 1.3016093537446258, 'num_leaves': 11, 'n_estimators': 370}
# AUC 0.899 params {'min_child_samples': 22, 'reg_alpha': 0.10040012531558401, 'reg_lambda': 2.90257080069576, 'num_leaves': 14, 'n_estimators': 689}
# AUC 0.883 params {'min_child_samples': 37, 'reg_alpha': 0.6966739634818181, 'reg_lambda': 0.8765967838736176, 'num_leaves': 33, 'n_estimators': 355}
# AUC 0.907 params {'min_child_samples': 68, 'reg_alpha': 1.1167964675613284, 'reg_lambda': 0.6361140319704712, 'num_leaves': 11, 'n_estimators': 342}
# AUC 0.898 params {'min_child_samples': 34, 'reg_alpha': 25.738764999472043, 'reg_lambda': 1.7550485119541162, 'num_leaves': 17, 'n_estimators': 321}
# AUC 0.905 params {'min_child_samples': 26, 'reg_alpha': 0.31762184309328917, 'reg_lambda': 0.5288312993192457, 'num_leaves': 10, 'n_estimators': 300}
# AUC 0.891 params {'min_child_samples': 30, 'reg_alpha': 1.31954252493778, 'reg_lambda': 6.724935706775236, 'num_leaves': 23, 'n_estimators': 380}
# AUC 0.900 params {'min_child_samples': 61, 'reg_alpha': 1.6875812743216096, 'reg_lambda': 1.0679259405424801, 'num_leaves': 13, 'n_estimators': 409}
# AUC 0.902 params {'min_child_samples': 48, 'reg_alpha': 0.40008915620845553, 'reg_lambda': 3.2819415034596697, 'num_leaves': 12, 'n_estimators': 394}
# AUC 0.892 params {'min_child_samples': 53, 'reg_alpha': 0.2267678281041202, 'reg_lambda': 2.6003617842304925, 'num_leaves': 22, 'n_estimators': 330}
# AUC 0.898 params {'min_child_samples': 42, 'reg_alpha': 0.15585856442988907, 'reg_lambda': 1.5518346441043513, 'num_leaves': 16, 'n_estimators': 362}
# AUC 0.897 params {'min_child_samples': 20, 'reg_alpha': 0.29394912201186596, 'reg_lambda': 5.7717524161235945, 'num_leaves': 18, 'n_estimators': 309}
# AUC 0.906 params {'min_child_samples': 31, 'reg_alpha': 0.1325874772587785, 'reg_lambda': 1.9258446322105556, 'num_leaves': 10, 'n_estimators': 317}
# AUC 0.906 params {'min_child_samples': 34, 'reg_alpha': 0.10804041098606892, 'reg_lambda': 2.2487467037029694, 'num_leaves': 12, 'n_estimators': 326}
# AUC 0.905 params {'min_child_samples': 27, 'reg_alpha': 0.17402238055793756, 'reg_lambda': 1.9230862768771328, 'num_leaves': 10, 'n_estimators': 341}
# AUC 0.901 params {'min_child_samples': 38, 'reg_alpha': 0.12429609973011836, 'reg_lambda': 1.3623588648695877, 'num_leaves': 14, 'n_estimators': 300}
# AUC 0.902 params {'min_child_samples': 24, 'reg_alpha': 0.13614053049168526, 'reg_lambda': 3.9777007837960565, 'num_leaves': 12, 'n_estimators': 317}
# AUC 0.905 params {'min_child_samples': 33, 'reg_alpha': 0.20058712273278853, 'reg_lambda': 2.0957025125341766, 'num_leaves': 11, 'n_estimators': 349}
# AUC 0.900 params {'min_child_samples': 30, 'reg_alpha': 0.11632543724497123, 'reg_lambda': 2.633368529794474, 'num_leaves': 14, 'n_estimators': 334}
# AUC 0.902 params {'min_child_samples': 36, 'reg_alpha': 0.151417632112223, 'reg_lambda': 1.5917229577970822, 'num_leaves': 13, 'n_estimators': 307}
# AUC 0.896 params {'min_child_samples': 28, 'reg_alpha': 0.25380899756809666, 'reg_lambda': 1.2595733213013551, 'num_leaves': 15, 'n_estimators': 322}
# AUC 0.900 params {'min_child_samples': 23, 'reg_alpha': 0.18228254860579512, 'reg_lambda': 3.315207666243555, 'num_leaves': 11, 'n_estimators': 336}
# AUC 0.904 params {'min_child_samples': 40, 'reg_alpha': 0.14820635067355925, 'reg_lambda': 2.828802949270524, 'num_leaves': 12, 'n_estimators': 356}
# AUC 0.909 params {'min_child_samples': 32, 'reg_alpha': 0.11187038687473215, 'reg_lambda': 1.6759409615369867, 'num_leaves': 10, 'n_estimators': 318}
# AUC 0.907 params {'min_child_samples': 26, 'reg_alpha': 0.1117727964813805, 'reg_lambda': 1.021659538737319, 'num_leaves': 10, 'n_estimators': 309}
# AUC 0.907 params {'min_child_samples': 22, 'reg_alpha': 0.21755895836350123, 'reg_lambda': 0.8780796589688928, 'num_leaves': 10, 'n_estimators': 330}
# AUC 0.899 params {'min_child_samples': 28, 'reg_alpha': 0.16301719436203174, 'reg_lambda': 1.740205958880656, 'num_leaves': 13, 'n_estimators': 347}
# AUC 0.906 params {'min_child_samples': 36, 'reg_alpha': 0.10027441874091098, 'reg_lambda': 1.2109702805850346, 'num_leaves': 11, 'n_estimators': 301}
# AUC 0.899 params {'min_child_samples': 32, 'reg_alpha': 0.11543478665394787, 'reg_lambda': 1.4531151018386859, 'num_leaves': 15, 'n_estimators': 371}
# AUC 0.907 params {'min_child_samples': 20, 'reg_alpha': 0.19774893987731987, 'reg_lambda': 0.7354211907830478, 'num_leaves': 10, 'n_estimators': 325}
# AUC 0.902 params {'min_child_samples': 45, 'reg_alpha': 0.25316397169563454, 'reg_lambda': 2.412496287093389, 'num_leaves': 13, 'n_estimators': 362}
# AUC 0.899 params {'min_child_samples': 24, 'reg_alpha': 0.12490015601357461, 'reg_lambda': 0.9615164086596175, 'num_leaves': 14, 'n_estimators': 339}
# AUC 0.904 params {'min_child_samples': 39, 'reg_alpha': 0.17438893177298265, 'reg_lambda': 1.1333386411305169, 'num_leaves': 11, 'n_estimators': 318}
# AUC 0.905 params {'min_child_samples': 29, 'reg_alpha': 0.1406266896856148, 'reg_lambda': 1.6336859494965357, 'num_leaves': 10, 'n_estimators': 301}
# AUC 0.898 params {'min_child_samples': 42, 'reg_alpha': 0.1013983553484465, 'reg_lambda': 1.9165920856646408, 'num_leaves': 16, 'n_estimators': 350}
# 100%|██████████| 600/600 [5:25:47<00:00, 32.58s/it, best loss: 0.09087641241492805]

# %%
best
# Out:
# {'min_child_samples': 33.0,
#  'n_estimators': 311.0,
#  'num_leaves': 11.0,
#  'reg_alpha': 0.1576758004066037,
#  'reg_lambda': 1.2185517017351772}

# %%
score = cross_val_score(estimator, x_train, y_train, scoring='roc_auc', cv=time_split)

print("score: ", score)
print("score: ", score.mean())
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-95-da12c871e9af> in <module>()
#       4                              reg_alpha=0.25, reg_lambda=0.25)
#       5 score = cross_val_score(estimator, x_train, y_train, scoring='roc_auc', cv=time_split)
# ----> 6 estimator.fit(x_train, y_train)
#       7 print("score: ", score)
#       8 print("score: ", score.mean())
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     742                                         verbose=verbose, feature_name=feature_name,
#     743                                         categorical_feature=categorical_feature,
# --> 744                                         callbacks=callbacks)
#     745         return self
#     746
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     542                               verbose_eval=verbose, feature_name=feature_name,
#     543                               categorical_feature=categorical_feature,
# --> 544                               callbacks=callbacks)
#     545
#     546         if evals_result:
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     240         booster.best_score[dataset_name][eval_name] = score
#     241     if not keep_training_booster:
# --> 242         booster.model_from_string(booster.model_to_string(), False).free_dataset()
#     243     return booster
#     244
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in model_from_string(self, model_str, verbose)
#    2052             c_str(model_str),
#    2053             ctypes.byref(out_num_iterations),
# -> 2054             ctypes.byref(self.handle)))
#    2055         out_num_class = ctypes.c_int(0)
#    2056         _safe_call(_LIB.LGBM_BoosterGetNumClasses(
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py in _safe_call(ret)
#      44     """
#      45     if ret != 0:
# ---> 46         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      47
#      48
#
# LightGBMError: Wrong size of feature_names

# %%
x_train.columns = ["feature_" + str(i) for i in range(0, x_train.shape[1])]

# %%
x_train.columns

# %%
time_split = TimeSeriesSplit(n_splits=7)
estimator = LGBMClassifier(boosting_type="goss",  class_weight='balanced',
                             num_leaves=31, n_estimators=400, random_state=42,
                             reg_alpha=0.25, reg_lambda=0.25)
estimator.fit(x_train, y_train)
# Out:
# LGBMClassifier(boosting_type='goss', class_weight='balanced', n_estimators=400,
#                random_state=42, reg_alpha=0.25, reg_lambda=0.25)

# %% [markdown]
# score:  0.9145039288638277

# %%
# predict
lgbm_pred = estimator.predict_proba(x_test)[:, 1]

# %%
# save Submission
save_submission(lgbm_pred, number=61)
